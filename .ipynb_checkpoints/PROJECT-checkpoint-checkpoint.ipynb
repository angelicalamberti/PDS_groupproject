# %% [markdown]
# # <span style= 'color: green'> **Where should I live?** </span> <br>
# ## Leveraging Data to Optimize Quality of Life Choices
# ### Group Project of Programming for Data Science 2025/26 <br>
# Angelica Lamberti 20250999 <br>
# Samuel Nazzaro 20251152 <br>
# Efe Oksuzz <br>
# Maddleine Rimmer

# %% [markdown]
#  <span style= 'color: red'>**Introduction** </span> <br> In the wake of increasing mobility across Europe, fueled by remote work, international education, and shifting social and economic priorities, there has been growing demand for tools that help citizens make better-informed decisions about where to live. <br>
#  <span style= 'color: red'> **Objectives** </span> <br>
# -Design a tool that translates complex country-level data into clear, actionable insights for everyday people: students seeking affordable education, professionals looking for better work-life balance, retirees interested in safety and healthcare, and more. <br>
# -Simplify this decision-making process by analyzing key characteristics of European countries, such as cost of living, safety, and employment. Through exploratory analysis, visualizations, and interpretable insights, the goal is to build a framework that empowers users to evaluate which countries align best with their personal values and life goals.

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## <span style= 'color: blue'> 1.  Data wrangling and analysis </span>

# %% [markdown]
# As a first step, our dataset (which is in a 'csv' format) is imported in Python.

# %%
data= pd.read_csv('city_data.csv', sep='|', header=1, parse_dates=['Last Data Update'])

num_rows, num_cols = data.shape
print(f"The dataset has {num_rows} rows and {num_cols} columns.")

data.head()
# Out:
# The dataset has 86 rows and 14 columns.
#                 City  Population Density  Population  Working Age Population   \
# 0    Vienna, Austria               310.0     2983513                2018818.0
# 1  Salzburg, Austria               243.0      375489                 250472.0
# 2  Brussels, Belgium               681.0     3284548                2137425.0
# 3   Antwerp, Belgium               928.0     1139663                 723396.0
# 4      Gent, Belgium               552.0      645813                 417832.0
#
#    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 0                    20.1               10.2         55770.0
# 1                    20.3                3.0         66689.0
# 2                    27.5               10.7         62500.0
# 3                    27.7                6.2         57595.0
# 4                    24.8                NaN         53311.0
#
#    Days of very strong heat stress              Main Spoken Languages  \
# 0                                3  German, English, Turkish, Serbian
# 1                                0                             German
# 2                                3     French, Dutch, Arabic, English
# 3                                3              Dutch, French, Arabic
# 4                                2                      Dutch, French
#
#    Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 0                    2500                 1050                    2061
# 1                    3200                 1100                    2186
# 2                    3350                 1200                    1900
# 3                    2609                  900                    1953
# 4                    2400                  827                    1200
#
#    Average Price Groceries Last Data Update
# 0                    340.0       2024-06-15
# 1                      NaN       2023-11-03
# 2                      NaN       2023-04-22
# 3                      NaN       2024-08-09
# 4                    120.0       2023-07-17

# %% [markdown]
# ### **Exploratory Analysis**
# **Question 1** How did you handle missing values and duplicate records in the dataset?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             86 non-null     object
#  1   Population Density               85 non-null     float64
#  2   Population                       86 non-null     int64
#  3   Working Age Population           85 non-null     float64
#  4   Youth Dependency Ratio           86 non-null     float64
#  5   Unemployment Rate                85 non-null     float64
#  6   GDP per Capita                   85 non-null     float64
#  7   Days of very strong heat stress  86 non-null     int64
#  8   Main Spoken Languages            85 non-null     object
#  9   Average Monthly Salary           86 non-null     int64
#  10  Avgerage Rent Price              86 non-null     int64
#  11  Average Cost of Living           86 non-null     int64
#  12  Average Price Groceries          6 non-null      float64
#  13  Last Data Update                 86 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(5), object(2)
# memory usage: 9.5+ KB

# %% [markdown]
# Since the Average Price Groceries column contains more than 90% missing values, it provides limited analytical value. Therefore, this variable will be excluded from further analysis. To preserve the integrity of the original dataset, a copy—named data_copy—is created, and all the changes will be applied to this duplicate.

# %%
data_copy=data.drop('Average Price Groceries', axis=1)
data_copy = data_copy.rename(columns={"Avgerage Rent Price": "Average Rent Price"})
data_copy
# Out:
#                   City  Population Density  Population  \
# 0      Vienna, Austria               310.0     2983513
# 1    Salzburg, Austria               243.0      375489
# 2    Brussels, Belgium               681.0     3284548
# 3     Antwerp, Belgium               928.0     1139663
# 4        Gent, Belgium               552.0      645813
# ..                 ...                 ...         ...
# 81   Stockholm, Sweden               334.0     2344124
# 82  Gothenburg, Sweden               245.0     1037675
# 83       Malmo, Sweden               368.0      680335
# 84     Ankara, Turkiye              1922.0     4843511
# 85      Adana, Turkiye               552.0     1074543
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 0                 2018818.0                    20.1               10.2
# 1                  250472.0                    20.3                3.0
# 2                 2137425.0                    27.5               10.7
# 3                  723396.0                    27.7                6.2
# 4                  417832.0                    24.8                NaN
# ..                      ...                     ...                ...
# 81                1534225.0                    28.5                6.2
# 82                 672152.0                    28.2                6.3
# 83                 436271.0                    29.4                9.2
# 84                3417691.0                    30.0               14.4
# 85                 718256.0                    37.8               12.2
#
#     GDP per Capita  Days of very strong heat stress  \
# 0          55770.0                                3
# 1          66689.0                                0
# 2          62500.0                                3
# 3          57595.0                                3
# 4          53311.0                                2
# ..             ...                              ...
# 81         70950.0                                0
# 82         49588.0                                0
# 83         44387.0                                0
# 84         38916.0                                3
# 85         19945.0                               59
#
#                 Main Spoken Languages  Average Monthly Salary  \
# 0   German, English, Turkish, Serbian                    2500
# 1                              German                    3200
# 2      French, Dutch, Arabic, English                    3350
# 3               Dutch, French, Arabic                    2609
# 4                       Dutch, French                    2400
# ..                                ...                     ...
# 81                   Swedish, English                    2700
# 82                   Swedish, English                    2500
# 83                   Swedish, English                    2400
# 84                            Turkish                     900
# 85                            Turkish                     750
#
#     Average Rent Price  Average Cost of Living Last Data Update
# 0                 1050                    2061       2024-06-15
# 1                 1100                    2186       2023-11-03
# 2                 1200                    1900       2023-04-22
# 3                  900                    1953       2024-08-09
# 4                  827                    1200       2023-07-17
# ..                 ...                     ...              ...
# 81                1400                    2300       2024-09-11
# 82                1200                    2100       2023-03-10
# 83                1100                    2000       2024-07-07
# 84                 450                     900       2023-06-08
# 85                 350                     800       2024-05-02
#
# [86 rows x 13 columns]

# %% [markdown]
# What about duplicate records?

# %%
data_copy['City'].describe()
# Out:
# count                  86
# unique                 84
# top       Berlin. Germany
# freq                    2
# Name: City, dtype: object

# %%
data_copy['City'].value_counts()
# Out:
# City
# Berlin. Germany           2
# Malaga, Spain             2
# Vienna, Austria           1
# Rotterdam, Netherlands    1
# The Hague, Netherlands    1
#                          ..
# Madrid, Spain             1
# Odense, Denmark           1
# Copenhagen, Denmark       1
# Hanover, Germany          1
# Adana, Turkiye            1
# Name: count, Length: 84, dtype: int64

# %% [markdown]
# The entries ‘Berlin, Germany’ and ‘Malaga, Spain’ appear twice in the dataset, indicating the potential presence of duplicate records. The next step is to verify whether these entries contain the same information. For this purpose, we will apply text-mining techniques to clean the dataset and have a more efficient access to its content. <br>
# In particular, since the ‘City’ column contains two distinct pieces of information—city and country—we aim to split it into two separate columns: one representing the city and the other the country.

# %%
citycountry_list=data_copy['City'].unique()
print (citycountry_list)
# Out:
# ['Vienna, Austria' 'Salzburg, Austria' 'Brussels, Belgium'
#  'Antwerp, Belgium' 'Gent, Belgium' 'Bruges, Belgium' 'Sofia, Bulgaria'
#  'Dobrich, Bulgaria' 'Zurich, Switzerland' 'Geneva, Switzerland'
#  'Basel, Switzerland' 'Lefkosia, Cyprus' 'Lemesos;Cyprus'
#  'Prague, Czechia' 'Ostrava, Czechia' 'Berlin. Germany' 'Hamburg, Germany'
#  'Munich, Germany' 'Cologne, Germany' 'Frankfurt am Main, Germany'
#  'Stuttgart, Germany' 'Leipzig, Germany' 'Dresden, Germany'
#  'Dusseldorf, Germany' 'Hanover, Germany' 'Copenhagen, Denmark'
#  'Odense, Denmark' 'Madrid, Spain' 'Barcelona, Spain' 'Valencia, Spain'
#  'Seville, Spain' 'Malaga, Spain' 'Tallinn, Estonia' 'Helsinki, Finland'
#  'Tampere, Finland' 'Paris, France' 'Lyon,  France' 'Toulouse, France'
#  'London, United Kingdom' 'Leeds, United Kingdom'
#  'Glasgow, United Kingdom' 'Liverpool, United Kingdom'
#  'Edinburgh, United Kingdom' 'Greece, Athens' 'Thessaloniki, Greece'
#  'Zagreb, Croatia' 'Split, Croatia' 'Budapest, Hungary' 'Miskolc, Hungary'
#  'Debrecen, Hungary' 'Dublin, Ireland' 'Cork, Ireland' 'Rome, Italy'
#  'Milan, Italy' 'Naples, Italy' 'Turin, Italy' 'Florence, Italy'
#  'Venice, Italy' 'Luxembourg, Luxembourg' 'Riga, Latvia' 'Malta, Malta'
#  'The Hague, Netherlands' 'Amsterdam, Netherlands'
#  'Rotterdam, Netherlands' 'Utrecht, Netherlands' 'Eindhoven, Netherlands'
#  'Oslo, Norway' 'Bergen, Norway' 'Stavanger, Norway' 'Warsaw, Poland'
#  'Lodz, Poland' 'Cracow, Poland' 'Lisbon, Portugal' 'Porto, Portugal'
#  'Braga, Portugal' 'Coimbra, Portugal' 'Giroc, Romania'
#  'Bratislava, Slovak Republic' 'Ljubljana, Slovenia' 'Stockholm, Sweden'
#  'Gothenburg, Sweden' 'Malmo, Sweden' 'Ankara, Turkiye' 'Adana, Turkiye']

# %%
data_copy = data_copy.rename(columns={'City': 'city&country'})

# %%
data_copy['city&country'] = data_copy['city&country'].str.replace('[;.]', ',', regex=True)\
    .str.replace(r'\s+', ' ', regex=True)\
    .str.strip()\
    .str.replace('Greece, Athens', 'Athens, Greece')

# %%
#Now we can delete duplicate rows
data_copy = data_copy.drop_duplicates(subset='city&country', keep='first')
data_copy = data_copy.reset_index(drop=True)
data_copy
# Out:
#           city&country  Population Density  Population  \
# 0      Vienna, Austria               310.0     2983513
# 1    Salzburg, Austria               243.0      375489
# 2    Brussels, Belgium               681.0     3284548
# 3     Antwerp, Belgium               928.0     1139663
# 4        Gent, Belgium               552.0      645813
# ..                 ...                 ...         ...
# 79   Stockholm, Sweden               334.0     2344124
# 80  Gothenburg, Sweden               245.0     1037675
# 81       Malmo, Sweden               368.0      680335
# 82     Ankara, Turkiye              1922.0     4843511
# 83      Adana, Turkiye               552.0     1074543
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 0                 2018818.0                    20.1               10.2
# 1                  250472.0                    20.3                3.0
# 2                 2137425.0                    27.5               10.7
# 3                  723396.0                    27.7                6.2
# 4                  417832.0                    24.8                NaN
# ..                      ...                     ...                ...
# 79                1534225.0                    28.5                6.2
# 80                 672152.0                    28.2                6.3
# 81                 436271.0                    29.4                9.2
# 82                3417691.0                    30.0               14.4
# 83                 718256.0                    37.8               12.2
#
#     GDP per Capita  Days of very strong heat stress  \
# 0          55770.0                                3
# 1          66689.0                                0
# 2          62500.0                                3
# 3          57595.0                                3
# 4          53311.0                                2
# ..             ...                              ...
# 79         70950.0                                0
# 80         49588.0                                0
# 81         44387.0                                0
# 82         38916.0                                3
# 83         19945.0                               59
#
#                 Main Spoken Languages  Average Monthly Salary  \
# 0   German, English, Turkish, Serbian                    2500
# 1                              German                    3200
# 2      French, Dutch, Arabic, English                    3350
# 3               Dutch, French, Arabic                    2609
# 4                       Dutch, French                    2400
# ..                                ...                     ...
# 79                   Swedish, English                    2700
# 80                   Swedish, English                    2500
# 81                   Swedish, English                    2400
# 82                            Turkish                     900
# 83                            Turkish                     750
#
#     Average Rent Price  Average Cost of Living Last Data Update
# 0                 1050                    2061       2024-06-15
# 1                 1100                    2186       2023-11-03
# 2                 1200                    1900       2023-04-22
# 3                  900                    1953       2024-08-09
# 4                  827                    1200       2023-07-17
# ..                 ...                     ...              ...
# 79                1400                    2300       2024-09-11
# 80                1200                    2100       2023-03-10
# 81                1100                    2000       2024-07-07
# 82                 450                     900       2023-06-08
# 83                 350                     800       2024-05-02
#
# [84 rows x 13 columns]

# %%
data_copy['City']=data_copy['city&country'].str.split(',', n=1, expand=True)[0] 
data_copy['Country']=data_copy['city&country'].str.split(',', n=1, expand=True)[1] 

data_copy['City'] = data_copy['City'].str.strip()
data_copy['Country'] = data_copy['Country'].str.strip()

data_copy
# Out:
#           city&country  Population Density  Population  \
# 0      Vienna, Austria               310.0     2983513
# 1    Salzburg, Austria               243.0      375489
# 2    Brussels, Belgium               681.0     3284548
# 3     Antwerp, Belgium               928.0     1139663
# 4        Gent, Belgium               552.0      645813
# ..                 ...                 ...         ...
# 79   Stockholm, Sweden               334.0     2344124
# 80  Gothenburg, Sweden               245.0     1037675
# 81       Malmo, Sweden               368.0      680335
# 82     Ankara, Turkiye              1922.0     4843511
# 83      Adana, Turkiye               552.0     1074543
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 0                 2018818.0                    20.1               10.2
# 1                  250472.0                    20.3                3.0
# 2                 2137425.0                    27.5               10.7
# 3                  723396.0                    27.7                6.2
# 4                  417832.0                    24.8                NaN
# ..                      ...                     ...                ...
# 79                1534225.0                    28.5                6.2
# 80                 672152.0                    28.2                6.3
# 81                 436271.0                    29.4                9.2
# 82                3417691.0                    30.0               14.4
# 83                 718256.0                    37.8               12.2
#
#     GDP per Capita  Days of very strong heat stress  \
# 0          55770.0                                3
# 1          66689.0                                0
# 2          62500.0                                3
# 3          57595.0                                3
# 4          53311.0                                2
# ..             ...                              ...
# 79         70950.0                                0
# 80         49588.0                                0
# 81         44387.0                                0
# 82         38916.0                                3
# 83         19945.0                               59
#
#                 Main Spoken Languages  Average Monthly Salary  \
# 0   German, English, Turkish, Serbian                    2500
# 1                              German                    3200
# 2      French, Dutch, Arabic, English                    3350
# 3               Dutch, French, Arabic                    2609
# 4                       Dutch, French                    2400
# ..                                ...                     ...
# 79                   Swedish, English                    2700
# 80                   Swedish, English                    2500
# 81                   Swedish, English                    2400
# 82                            Turkish                     900
# 83                            Turkish                     750
#
#     Average Rent Price  Average Cost of Living Last Data Update        City  \
# 0                 1050                    2061       2024-06-15      Vienna
# 1                 1100                    2186       2023-11-03    Salzburg
# 2                 1200                    1900       2023-04-22    Brussels
# 3                  900                    1953       2024-08-09     Antwerp
# 4                  827                    1200       2023-07-17        Gent
# ..                 ...                     ...              ...         ...
# 79                1400                    2300       2024-09-11   Stockholm
# 80                1200                    2100       2023-03-10  Gothenburg
# 81                1100                    2000       2024-07-07       Malmo
# 82                 450                     900       2023-06-08      Ankara
# 83                 350                     800       2024-05-02       Adana
#
#     Country
# 0   Austria
# 1   Austria
# 2   Belgium
# 3   Belgium
# 4   Belgium
# ..      ...
# 79   Sweden
# 80   Sweden
# 81   Sweden
# 82  Turkiye
# 83  Turkiye
#
# [84 rows x 15 columns]

# %% [markdown]
# **Question 2.a** Which country appears most frequently in the dataset? How many cities are associated with it?

# %%
countries_count = data_copy['Country'].value_counts()
print(countries_count)
top_country = countries_count.idxmax()
top_count = countries_count.max()

print(f"The country with the highest number of entries is {top_country} with {top_count} occurrences.")
# Out:
# Country
# Germany            10
# Italy               6
# Spain               5
# Netherlands         5
# United Kingdom      5
# Belgium             4
# Portugal            4
# Hungary             3
# Sweden              3
# Switzerland         3
# Poland              3
# Norway              3
# France              3
# Ireland             2
# Austria             2
# Croatia             2
# Greece              2
# Finland             2
# Denmark             2
# Czechia             2
# Cyprus              2
# Bulgaria            2
# Turkiye             2
# Luxembourg          1
# Latvia              1
# Malta               1
# Estonia             1
# Romania             1
# Slovak Republic     1
# Slovenia            1
# Name: count, dtype: int64
# The country with the highest number of entries is Germany with 10 occurrences.

# %%
german_cities = data_copy.loc[data_copy['Country'] == 'Germany', 'City'].unique()

print("Cities associated with Germany:")
for city in german_cities:
    print("-", city)
# Out:
# Cities associated with Germany:
# - Berlin
# - Hamburg
# - Munich
# - Cologne
# - Frankfurt am Main
# - Stuttgart
# - Leipzig
# - Dresden
# - Dusseldorf
# - Hanover

# %% [markdown]
# **Question 2.b** How many cities are present in total? How many are associated with Greece?

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   city&country                     84 non-null     object
#  1   Population Density               83 non-null     float64
#  2   Population                       84 non-null     int64
#  3   Working Age Population           83 non-null     float64
#  4   Youth Dependency Ratio           84 non-null     float64
#  5   Unemployment Rate                83 non-null     float64
#  6   GDP per Capita                   83 non-null     float64
#  7   Days of very strong heat stress  84 non-null     int64
#  8   Main Spoken Languages            83 non-null     object
#  9   Average Monthly Salary           84 non-null     int64
#  10  Average Rent Price               84 non-null     int64
#  11  Average Cost of Living           84 non-null     int64
#  12  Last Data Update                 84 non-null     datetime64[ns]
#  13  City                             84 non-null     object
#  14  Country                          84 non-null     object
# dtypes: datetime64[ns](1), float64(5), int64(5), object(4)
# memory usage: 10.0+ KB

# %%
columns=data_copy.columns.to_list()
data_copy = data_copy[columns[-2:] + columns[:-2]]
data_copy=data_copy.drop('city&country', axis=1)
#Putting the city and country columns as the first and second ones: it's better for visualization.

# %%
cities_sum = data_copy['City'].value_counts().sum()

cities_count=data_copy['Country'].value_counts()
print(cities_count)

greece_unique_cities = data_copy.loc[data_copy['Country'] == 'Greece', 'City'].nunique()
print('In total there are', cities_sum, 'cities.')
print("Number of cities associated with Greece:", greece_unique_cities)
# Out:
# Country
# Germany            10
# Italy               6
# Spain               5
# Netherlands         5
# United Kingdom      5
# Belgium             4
# Portugal            4
# Hungary             3
# Sweden              3
# Switzerland         3
# Poland              3
# Norway              3
# France              3
# Ireland             2
# Austria             2
# Croatia             2
# Greece              2
# Finland             2
# Denmark             2
# Czechia             2
# Cyprus              2
# Bulgaria            2
# Turkiye             2
# Luxembourg          1
# Latvia              1
# Malta               1
# Estonia             1
# Romania             1
# Slovak Republic     1
# Slovenia            1
# Name: count, dtype: int64
# In total there are 84 cities.
# Number of cities associated with Greece: 2

# %% [markdown]
# **Question 2.c** Which is the least spoken language in the dataset? Which are the top 3 most spoken languages?

# %%
#Cleaning the 'Main Spoken Language Column'

data_copy['Languages'] = data_copy['Main Spoken Languages'].str.split(',')
lan = data_copy['Languages'].explode().dropna()
lan = lan.str.strip()
count = lan.value_counts()
    
most_spoken_3=lan.value_counts().head(3)
least_spoken=lan.value_counts().idxmin()
print("Most spoken top 3", most_spoken_3)
print("Least spoken language is", least_spoken)
# Out:
# Most spoken top 3 Languages
# English    46
# German     14
# Turkish    10
# Name: count, dtype: int64
# Least spoken language is Latvian

# %% [markdown]
# At third place, with 10 occurrencies we have both Turkish and French. The least spoken languages are Latvian, Maltese, Serbian, Romanian, Slovak, ScotsGaelic, Luxemboutgish, Scots, Bengali, Estonian, Valencian, Catalan and Slovene. Each of these languages occurs only once.

# %% [markdown]
# **Question 3.a** Entries uploaded before April 2023 need to be updated. Which cities would require an update?

# %%
begin_April_23=pd.to_datetime('2023-04-1')
filter=data_copy[data_copy['Last Data Update']< begin_April_23]
filter['City']
# Out:
# 10                Basel
# 17               Munich
# 19    Frankfurt am Main
# 36                 Lyon
# 57               Venice
# 80           Gothenburg
# Name: City, dtype: object

# %% [markdown]
# The cities Basel, Munich, Frankfurt am Main, Lyon, Venice, and Gothenburg require an update, as their most recent data revisions date back to before April 2023.

# %% [markdown]
# **Question 3.b** How many days ago was the last update? On what day, month, and year did it occur?

# %%
date_today= pd.Timestamp('today').normalize()
last_update=max(data_copy['Last Data Update'])
days= (date_today-last_update).days
print('The last update was', days, 'days ago')
print('The last update was on', last_update)
# Out:
# The last update was 364 days ago
# The last update was on 2024-12-12 00:00:00

# %% [markdown]
# **Question 4.a** How are the Unemployment Rate and GDP per Capita distributed and related? What does this relationship suggest? Provide a visual representation.

# %%
unemployment_rate=data_copy['Unemployment Rate']
GDP_per_capita=data_copy['GDP per Capita']

#We can drop the missing values from these columns
unempl_GDP = data_copy.loc[:, ('Unemployment Rate', 'GDP per Capita')].dropna(subset=["Unemployment Rate", "GDP per Capita"])
unempl_GDP
# Out:
#     Unemployment Rate  GDP per Capita
# 0                10.2         55770.0
# 1                 3.0         66689.0
# 2                10.7         62500.0
# 3                 6.2         57595.0
# 5                 5.6         63083.0
# ..                ...             ...
# 79                6.2         70950.0
# 80                6.3         49588.0
# 81                9.2         44387.0
# 82               14.4         38916.0
# 83               12.2         19945.0
#
# [82 rows x 2 columns]

# %%
#How are Unemployement Rate and GDP per Capita distributed?
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.histplot(unemployment_rate, kde=True, color='skyblue')
plt.title('Distribution of Unemployment Rate')

plt.subplot(1,2,2)
sns.histplot(GDP_per_capita, kde=True, color='lightgreen')
plt.title('Distribution of GDP per Capita')

plt.tight_layout()
plt.show()

# %%
#Relationship between GDP per Capita and Unemployment Rate
plt.figure(figsize=(7,5))
sns.scatterplot(data=unempl_GDP, x= 'Unemployment Rate', y= 'GDP per Capita')
sns.regplot(data=unempl_GDP, x= 'Unemployment Rate', y= 'GDP per Capita', scatter=False, color='red')
plt.title('Relationship between GDP per Capita and Unemployment Rate')
plt.show()

# %% [markdown]
# The scatter plot illustrates the relationship between GDP per Capita and the Unemployment Rate.
# The trend line shows a negative correlation between the two variables: as the unemployment rate increases, GDP per capita tends to decrease. This suggests that cities with higher unemployment rates generally exhibit lower levels of economic productivity per person.
# However, the dispersion of data points indicates a certain degree of variability: some locations deviate from the general trend, showing relatively high GDP per capita even with moderate unemployment rates. The shaded region around the regression line suggest that while the overall relationship is negative, it is not perfectly linear.
# Let's calclulate the Pearson correlation coefficient (we expect it to be negative).

# %%
corr = data_copy['GDP per Capita'].corr(data_copy['Unemployment Rate'])
print(f"Correlation: {corr:.2f}")
# Out:
# Correlation: -0.34

# %% [markdown]
# **Question 4.b** Which are the top 5 cities with the largest difference between the Average Monthly Salary and Average Cost of Living? What about the top 5 countries with the smallest average difference? Show these results with meaningful visualizations.

# %%
#top 5 cities with the largest difference between the Average Monthly Salary and Average Cost of Living
data_copy['diff']=data_copy['Average Monthly Salary']-data_copy['Average Cost of Living']
top5 = data_copy.sort_values(by='diff', ascending=False).head(5)
top5
# Out:
#         City      Country  Population Density  Population  \
# 10     Basel  Switzerland               793.0      550152
# 34   Tampere      Finland                65.0      444370
# 33  Helsinki      Finland               322.0     1507140
# 8     Zurich  Switzerland              1058.0     1384728
# 9     Geneva  Switzerland              1112.0      597269
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 10                 358020.0                    21.5                5.3
# 34                 283876.0                    25.6                6.6
# 33                1004835.0                    25.1                6.6
# 8                  939270.0                    22.3                4.7
# 9                  404313.0                    23.8                9.9
#
#     GDP per Capita  Days of very strong heat stress  \
# 10         94826.0                                5
# 34         41954.0                                0
# 33         59502.0                                0
# 8          80431.0                                4
# 9          83747.0                                1
#
#         Main Spoken Languages  Average Monthly Salary  Average Rent Price  \
# 10    German, English, French                    6366                2500
# 34                    Finnish                    3500                 850
# 33  Finnish, Swedish, English                    3900                1050
# 8             German, English                    6636                3190
# 9             French, English                    5794                2818
#
#     Average Cost of Living Last Data Update                      Languages  \
# 10                    4239       2023-01-19    [German,  English,  French]
# 34                    1600       2024-04-29                      [Finnish]
# 33                    2050       2023-09-12  [Finnish,  Swedish,  English]
# 8                     4862       2023-05-06             [German,  English]
# 9                     4263       2024-09-28             [French,  English]
#
#     diff
# 10  2127
# 34  1900
# 33  1850
# 8   1774
# 9   1531

# %% [markdown]
# The top 5 cities with the largest difference between the Average Monthly Salary and Average Cost of Living are:
# 1. Basel
# 2. Tampere
# 3. Helsinki
# 4. Zurich
# 5. Geneva

# %%
# top 5 countries with the smallest average difference
avg_diff = data_copy.groupby('Country')['diff'].mean()

top5_smallest = avg_diff.sort_values().head(5)

print("Top 5 countries with the smallest average difference between Average Monthly Salary and Average Cost of Living:")
for country, diff_value in top5_smallest.items():
    print(f"- {country}: average difference = {diff_value}")
# Out:
# Top 5 countries with the smallest average difference between Average Monthly Salary and Average Cost of Living:
# - Portugal: average difference = -207.5
# - Greece: average difference = -125.0
# - Slovak Republic: average difference = -50.0
# - Turkiye: average difference = -25.0
# - Poland: average difference = -16.666666666666668

# %%
#Visualization 
plt.figure(figsize=(8, 5))

plt.bar(top5_smallest.index, top5_smallest.values)
plt.title("Top 5 countries with the smallest average difference\nbetween Average Monthly Salary and Cost of Living")
plt.xlabel("Country")
plt.ylabel("Average difference (Salary - Cost of Living)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#Visualization
plt.figure(figsize=(10, 6))

city_labels = top5['City'] + " (" + top5['Country'] + ")"

plt.bar(city_labels, top5['diff'])
plt.title("Top 5 cities with the largest difference\nbetween Average Monthly Salary and Cost of Living")
plt.xlabel("City")
plt.ylabel("Difference (Salary - Cost of Living)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Question 4.c** Which is the best city for someone seeking: <br>
# -An average monthly salary above €2000; <br>
# -A cost of living below or equal to €1600 <br>
# -A country suitable for starting a family (with a relatively larger youth population)?

# %%
data_copy=data_copy.drop(columns=['diff'])
youth_mean=data_copy['Youth Dependency Ratio'].mean()
data_copy[(data_copy['Average Monthly Salary']>2000)&(data_copy['Average Cost of Living']<=1600)&(data_copy['Youth Dependency Ratio']>youth_mean)]
# Out:
#         City  Country  Population Density  Population  \
# 4       Gent  Belgium               552.0      645813
# 30   Seville    Spain               330.0     1549641
# 34   Tampere  Finland                65.0      444370
# 37  Toulouse   France              4300.0      511684
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 4                  417832.0                   24.80                NaN
# 30                1037225.0                   25.00               21.6
# 34                 283876.0                   25.60                6.6
# 37                 401425.0                   27.31                8.5
#
#     GDP per Capita  Days of very strong heat stress Main Spoken Languages  \
# 4          53311.0                                2         Dutch, French
# 30         30004.0                               53               Spanish
# 34         41954.0                                0               Finnish
# 37         46226.0                               14                French
#
#     Average Monthly Salary  Average Rent Price  Average Cost of Living  \
# 4                     2400                 827                    1200
# 30                    2300                 650                    1150
# 34                    3500                 850                    1600
# 37                    2600                 800                    1600
#
#    Last Data Update         Languages
# 4        2023-07-17  [Dutch,  French]
# 30       2024-09-01         [Spanish]
# 34       2024-04-29         [Finnish]
# 37       2024-02-20          [French]

# %% [markdown]
# The best city for someone seeking the characteristics above is Touluse, since it has the highest rate of young population and meets the other conditions too.
# Also Seville, Gent and Tempere are suitable cities for someone looking for these features.

# %% [markdown]
# **Question 5** What are three additional insights you find meaningful when comparing the given cities?

# %% [markdown]
# ### Insight 1: Youth Dependency Ratio vs Working Age Population
# Cities with a high Youth Dependency Ratio have a larger share of young people relative to the working-age population. Cities with a larger Working Age Population have a stronger active labor force.
# This analysis helps identify which cities are more likely to face better future labor challenges.

# %%
plt.figure(figsize=(10, 7))

# Scatter plot
plt.scatter(data_copy["Working Age Population "], data_copy["Youth Dependency Ratio"], s=60)

# City labels
for _, row in data_copy.iterrows():
    plt.text(
        row["Working Age Population "], 
        row["Youth Dependency Ratio"], 
        row["City"],
        fontsize=8,
        ha='left',
        va='bottom'
    )

plt.xlabel("Working Age Population")
plt.ylabel("Youth Dependency Ratio")
plt.title("Youth Dependency Ratio vs Working Age Population")

plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# The scatter plot shows how cities differ in their demographic structure by comparing Working Age Population and Youth Dependency Ratio. <br>
# 1. Large metropolitan cities
# Cities like London, Madrid, Barcelona, Berlin, Rome have very large working-age populations and moderate youth dependency. <br>
# 2. Smaller cities with high youth dependency
# Cities such as Adana, Ankara, Cork, Stavanger have high youth dependency ratios and smaller working-age populations. These cities have younger populations and may face more pressure on education services. <br>
# 3. Most European cities cluster in a balanced zone, showing a mid-range working-age populations and youth dependency around 22–27%. This may indicate that they have balanced demographic profiles.

# %%
print(data_copy.columns)
# Out:
# Index(['City', 'Country', 'Population Density', 'Population',
#        'Working Age Population ', 'Youth Dependency Ratio',
#        'Unemployment Rate', 'GDP per Capita',
#        'Days of very strong heat stress', 'Main Spoken Languages',
#        'Average Monthly Salary', 'Average Rent Price',
#        'Average Cost of Living', 'Last Data Update', 'Languages'],
#       dtype='object')

# %% [markdown]
# ### Insight 2: Unemployment vs Salary
# Comparing unemployment rate and average salary across cities helps reveal economic strength: cities with high salaries and low unemployment tend to have, strong labor markets and high productivity; meanwhile cities with high unemployment and low salaries may indicate weaker job markets.

# %%
plt.figure(figsize=(10, 7))

plt.scatter(data_copy["Unemployment Rate"], data_copy["Average Monthly Salary"], s=60)

for _, row in data_copy.iterrows():
    plt.text(
        row["Unemployment Rate"],
        row["Average Monthly Salary"],
        row["City"],
        fontsize=8,
        ha='left',
        va='bottom'
    )

plt.xlabel("Unemployment Rate (%)")
plt.ylabel("Average Monthly Salary")
plt.title("Unemployment Rate vs Average Monthly Salary")

plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# The scatter plot shows that cities like Zurich, Basel, and Geneva have very high salaries and low unemployment, indicating strong and productive labor markets. Many Northern and Western European cities (Amsterdam, Copenhagen, Helsinki, Munich) group together with moderate unemployment and middle-high salaries. In contrast, several Southern and Eastern European cities—such as Naples, Thessaloniki, Athens, Adana, and Ankara—show high unemployment and significantly lower salaries, highlighting weaker labor market performance. Cities like Valencia, Madrid, Barcelona fall in the middle, with moderate salaries but elevated unemployment.

# %% [markdown]
# ### Insight 3: heat-stress
# The number of days with very strong heat stress is an important factor for assessing quality of life and health risks, especially for children, the elderly and people with medical conditions.
# In addition to this, frequent heat-stress days can increase energy costs (e.g., air conditioning) and affect productivity. From a long-term perspective, this indicator also signals climate resilience: cities with fewer extreme-heat days may offer a more stable, comfortable environment. Overall heat stress is an important factor to think about when evaluating long-term livability.

# %%
data_copy_sorted = data_copy.dropna(subset=["Days of very strong heat stress"]).sort_values("Days of very strong heat stress", ascending=False)
plt.figure(figsize=(14, 6))

plt.bar(data_copy_sorted["City"], data_copy_sorted["Days of very strong heat stress"])

plt.title("Days of Very Strong Heat Stress by City")
plt.xlabel("City")
plt.ylabel("Days of Very Strong Heat Stress")
plt.xticks(rotation=90)        
plt.tight_layout()
plt.grid(axis="y", linestyle="--", alpha=0.4)

plt.show()

# %% [markdown]
# The chart shows that southern cities like Adana, Seville, Lefkosia, and Athens experience very high numbers of extreme heat-stress days, suggesting significant climate pressure and low comfort during summer. As expected, many Northern cities—such as Edinburgh, Dublin, Copenhagen, Helsinki, and Stockholm have almost no heat-stress days, indicating much cooler and more stable conditions.

# %% [markdown]
# ## <span style= 'color: blue'> 2. Interactive Map </span>

# %% [markdown]
# The goal of this section is to create an interactive map of Europe where users can explore cities and view relevant information such as country, population, average salary, and cost of living.

# %% [markdown]
# ### Web scraping

# %%
# !pip install beautifulsoup4   
# !pip install selenium 
# !pip install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: selenium in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (4.38.0)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio<1.0,>=0.31.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from selenium) (0.32.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.10.5 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from selenium) (2025.11.12)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (24.3.0)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (3.7)
# Requirement already satisfied: outcome in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.1)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.16.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from requests) (2025.11.12)

# %% [markdown]
# For the web scraping procedure, Selenium was used to automatically navigate Wikipedia, search for each city, and extract geographic coordinates from the corresponding city pages. In some cases (e.g., Split and Cork), the original city names had to be adjusted (such as “Split, Croatia” and “Cork (city)”) to correctly match the corresponding Wikipedia page. <br>
# Madrid does not provide coordinates on Wikipedia, which resulted in a missing value during the scraping process. For this reason, the coordinates of Madrid were manually  added using an external and reliable source (Google). Conceptually, this value can be treated as a missing observation, and therefore it would have also been acceptable to drop this entry from the dataset.

# %%
#necessary library are imported
from bs4 import BeautifulSoup        
import requests  
from urllib.parse import quote

# %%
cities=data_copy['City'].str.replace('Gent', 'Ghent').str.replace('Split','Split, Croatia').str.replace ('Cork', 'Cork (city)').to_list()

# %%
def get_coords(city):

    url = f"https://en.wikipedia.org/wiki/{quote(city.replace(' ', '_'))}"
    
    headers = {"User-Agent": "Mozilla/5.0"} 
    r = requests.get(url, headers=headers)
    
    if r.status_code != 200:
        return None, None
    
    soup = BeautifulSoup(r.text, "html.parser")
    
    lat_tag = soup.find("span", class_="latitude")
    lon_tag = soup.find("span", class_="longitude")
    
    if lat_tag and lon_tag:
        return lat_tag.text, lon_tag.text
    else:
        return None, None
    


latitude = []
longitude = []

for city in cities:
    lat, lon = get_coords(city)
    latitude.append(lat)
    longitude.append(lon)
    print(f"{city}  {lat}, {lon}")

data_copy["latitude"] = latitude
data_copy["longitude"] = longitude
# Out:
# Vienna  48°12′30″N, 16°22′21″E
# Salzburg  47°48′00″N, 13°02′42″E
# Brussels  50°50′48″N, 04°21′09″E
# Antwerp  51°13′04″N, 04°24′01″E
# Ghent  51°03′13″N, 03°43′31″E
# Bruges  51°12′32″N, 03°13′27″E
# Sofia  42°42′N, 23°20′E
# Dobrich  43°34′N, 27°50′E
# Zurich  47°22′28″N, 08°32′28″E
# Geneva  46°12′06″N, 06°08′49″E
# Basel  47°33′17″N, 07°35′26″E
# Lefkosia  35°10′21″N, 33°21′54″E
# Lemesos  34°40′29″N, 33°02′39″E
# Prague  50°5′15″N, 14°25′17″E
# Ostrava  49°50′8″N, 18°17′33″E
# Berlin  52°31′12″N, 13°24′18″E
# Hamburg  53°33′N, 10°00′E
# Munich  48°08′15″N, 11°34′30″E
# Cologne  50°56′11″N, 6°57′10″E
# Frankfurt am Main  50°06′38″N, 08°40′56″E
# Stuttgart  48°46′39″N, 09°10′48″E
# Leipzig  51°20′24″N, 12°22′30″E
# Dresden  51°03′00″N, 13°44′24″E
# Dusseldorf  51°13′32″N, 6°46′36″E
# Hanover  52°22′N, 9°43′E
# Copenhagen  55°40′34″N, 12°34′06″E
# Odense  55°23′45″N, 10°23′19″E
# Madrid  40°30′N, 3°40′W
# Barcelona  41°23′N, 2°11′E
# Valencia  39°28′12″N, 00°22′35″W
# Seville  37°23′24″N, 5°59′24″W
# Malaga  36°43′10″N, 4°25′12″W
# Tallinn  59°26′14″N, 24°44′43″E
# Helsinki  60°10′15″N, 24°56′15″E
# Tampere  61°29′53″N, 23°45′36″E
# Paris  48°51′24″N, 2°21′8″E
# Lyon  45°46′03″N, 4°50′06″E
# Toulouse  43°36′16″N, 1°26′38″E
# London  51°30′26″N, 0°7′39″W
# Leeds  53°47′51″N, 01°32′37″W
# Glasgow  55°51′40″N, 04°15′00″W
# Liverpool  53°24′26″N, 2°59′30″W
# Edinburgh  55°57′12″N, 3°11′21″W
# Athens  37°59′03″N, 23°43′41″E
# Thessaloniki  40°38′25″N, 22°56′8″E
# Zagreb  45°48′47″N, 15°58′39″E
# Split, Croatia  43°30′36″N, 16°26′24″E
# Budapest  47°29′33″N, 19°03′05″E
# Miskolc  48°06′15″N, 20°47′30″E
# Debrecen  47°31′54″N, 21°37′28″E
# Dublin  53°21′00″N, 06°15′37″W
# Cork (city)  51°53′50″N, 8°28′12″W
# Rome  41°53′36″N, 12°28′58″E
# Milan  45°28′01″N, 09°11′24″E
# Naples  40°50′9″N, 14°14′55″E
# Turin  45°04′45″N, 07°40′34″E
# Florence  43°46′17″N, 11°15′15″E
# Venice  45°26′15″N, 12°20′9″E
# Luxembourg  49°49′N, 6°08′E
# Riga  56°56′56″N, 24°6′23″E
# Malta  35°54′N, 14°31′E
# The Hague  52°04′48″N, 04°18′36″E
# Amsterdam  52°22′22″N, 04°53′37″E
# Rotterdam  51°55′N, 4°29′E
# Utrecht  52°05′27″N, 05°07′18″E
# Eindhoven  51°26′N, 5°29′E
# Oslo  59°54′48″N, 10°44′20″E
# Bergen  60°23′22″N, 5°19′48″E
# Stavanger  58°58′12″N, 05°43′53″E
# Warsaw  52°13′48″N, 21°00′40″E
# Lodz  51°46′37″N, 19°27′17″E
# Cracow  50°03′41″N, 19°56′14″E
# Lisbon  38°43′31″N, 09°09′00″W
# Porto  41°9′0″N, 8°36′39″W
# Braga  41°33′4″N, 8°25′42″W
# Coimbra  40°12′10″N, 8°24′50″W
# Giroc  45°42′N, 21°14′E
# Bratislava  48°08′38″N, 17°06′35″E
# Ljubljana  46°03′05″N, 14°30′22″E
# Stockholm  59°19′46″N, 18°4′7″E
# Gothenburg  57°42′27″N, 11°58′03″E
# Malmo  55°36′21″N, 13°02′09″E
# Ankara  39°55′44″N, 32°51′17″E
# Adana  37°0′N, 35°19.28′E

# %%
data_copy.head()
# Out:
#        City  Country  Population Density  Population  Working Age Population   \
# 0    Vienna  Austria               310.0     2983513                2018818.0
# 1  Salzburg  Austria               243.0      375489                 250472.0
# 2  Brussels  Belgium               681.0     3284548                2137425.0
# 3   Antwerp  Belgium               928.0     1139663                 723396.0
# 4      Gent  Belgium               552.0      645813                 417832.0
#
#    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 0                    20.1               10.2         55770.0
# 1                    20.3                3.0         66689.0
# 2                    27.5               10.7         62500.0
# 3                    27.7                6.2         57595.0
# 4                    24.8                NaN         53311.0
#
#    Days of very strong heat stress              Main Spoken Languages  \
# 0                                3  German, English, Turkish, Serbian
# 1                                0                             German
# 2                                3     French, Dutch, Arabic, English
# 3                                3              Dutch, French, Arabic
# 4                                2                      Dutch, French
#
#    Average Monthly Salary  Average Rent Price  Average Cost of Living  \
# 0                    2500                1050                    2061
# 1                    3200                1100                    2186
# 2                    3350                1200                    1900
# 3                    2609                 900                    1953
# 4                    2400                 827                    1200
#
#   Last Data Update                               Languages    latitude  \
# 0       2024-06-15  [German,  English,  Turkish,  Serbian]  48°12′30″N
# 1       2023-11-03                                [German]  47°48′00″N
# 2       2023-04-22     [French,  Dutch,  Arabic,  English]  50°50′48″N
# 3       2024-08-09               [Dutch,  French,  Arabic]  51°13′04″N
# 4       2023-07-17                        [Dutch,  French]  51°03′13″N
#
#     longitude
# 0  16°22′21″E
# 1  13°02′42″E
# 2  04°21′09″E
# 3  04°24′01″E
# 4  03°43′31″E

# %%
# Coordinates of Madrid
madrid_lat = "40°25′10″N"
madrid_lon = "3°42′14″W"
# Set coordinates for all rows where city == "Madrid"
mask = data_copy["City"] == "Madrid"
data_copy.loc[mask, "latitude"] = madrid_lat
data_copy.loc[mask, "longitude"] = madrid_lon

# %%
#double check 
data_copy[data_copy['City']=='Madrid']
# Out:
#       City Country  Population Density  Population  Working Age Population   \
# 27  Madrid   Spain               873.0     6882461                4617753.0
#
#     Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 27                    23.0               10.8         51020.0
#
#     Days of very strong heat stress Main Spoken Languages  \
# 27                               18               Spanish
#
#     Average Monthly Salary  Average Rent Price  Average Cost of Living  \
# 27                    2271                1100                    1589
#
#    Last Data Update  Languages    latitude  longitude
# 27       2023-05-14  [Spanish]  40°25′10″N  3°42′14″W

# %% [markdown]
# ### Interactive Map

# %% [markdown]
# In this step we build an interactive map of European cities using the geographic coordinates previously scraped.
# With geopandas we load a polygon map of Europe and convert our data_copy table of cities into a GeoDataFrame of points.
# Each city is displayed as a marker on the map; when the user hovers on a marker, a popup shows: <br>
# -The country <br>
# -The population <br>
# -The average monthly salary <br>
# -The average cost of living <br>

# %%
# !pip install geopandas
# !pip install geopy
# !pip install geodatasets
# Out:
# Requirement already satisfied: geopandas in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (0.14.4)
# Requirement already satisfied: fiona>=1.8.21 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from geopandas) (1.10.1)
# Requirement already satisfied: numpy>=1.22 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from geopandas) (2.2.6)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=1.4.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from geopandas) (2.3.2)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=1.8.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: attrs>=19.2.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from fiona>=1.8.21->geopandas) (24.3.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from fiona>=1.8.21->geopandas) (2025.11.12)
# Requirement already satisfied: click~=8.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from fiona>=1.8.21->geopandas) (8.3.1)
# Requirement already satisfied: click-plugins>=1.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from fiona>=1.8.21->geopandas) (1.1.1.2)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)
# Requirement already satisfied: geopy in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from geopy) (2.1)
# Requirement already satisfied: geodatasets in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (2024.8.0)
# Requirement already satisfied: pooch in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from geodatasets) (1.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from pooch->geodatasets) (4.3.7)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from pooch->geodatasets) (25.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from pooch->geodatasets) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from requests>=2.19.0->pooch->geodatasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from requests>=2.19.0->pooch->geodatasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from requests>=2.19.0->pooch->geodatasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/PDS/lib/python3.13/site-packages (from requests>=2.19.0->pooch->geodatasets) (2025.11.12)

# %%
#Necessary library are imported
import geopandas as gpd

# %% [markdown]
# *Check*: are there missing values in the columns that contain the information we want to include in the map?

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             84 non-null     object
#  1   Country                          84 non-null     object
#  2   Population Density               83 non-null     float64
#  3   Population                       84 non-null     int64
#  4   Working Age Population           83 non-null     float64
#  5   Youth Dependency Ratio           84 non-null     float64
#  6   Unemployment Rate                83 non-null     float64
#  7   GDP per Capita                   83 non-null     float64
#  8   Days of very strong heat stress  84 non-null     int64
#  9   Main Spoken Languages            83 non-null     object
#  10  Average Monthly Salary           84 non-null     int64
#  11  Average Rent Price               84 non-null     int64
#  12  Average Cost of Living           84 non-null     int64
#  13  Last Data Update                 84 non-null     datetime64[ns]
#  14  Languages                        83 non-null     object
#  15  latitude                         84 non-null     object
#  16  longitude                        84 non-null     object
# dtypes: datetime64[ns](1), float64(5), int64(5), object(6)
# memory usage: 11.3+ KB

# %% [markdown]
# In order to build a GeoDataFrame of city points and overlay them on a polygon map of Europe, we have to convert city coordinates from DMS string to decimal degrees. In addition to this a copy of the dataset is created to preserve the structure of the cleaned dataframe
# (data_copy).

# %%
df = data_copy.copy()

# Convert datetime columns to string to avoid JSON / serialization errors in interactive maps.

for col in df.columns:
    if np.issubdtype(df[col].dtype, np.datetime64):
        df[col] = df[col].astype(str)

# DMS string → decimal degrees

def dms_to_decimal(value):
    s = str(value).strip()

    # Handle empty / None / 'nan'
    if s.lower() in ("none", "", "nan"):
        return np.nan

    # If there are no DMS symbols and no N/S/E/W, try direct float
    if not any(ch in s.upper() for ch in ["N", "S", "E", "W", "°", "′", "”", "″"]):
        try:
            return float(s)
        except ValueError:
            return np.nan

    # South and West are negative
    sign = -1 if ("S" in s.upper() or "W" in s.upper()) else 1

    # Extract numeric parts: degrees, minutes, seconds
    nums = re.findall(r"\d+", s)
    if len(nums) == 0:
        return np.nan

    degrees = float(nums[0])
    minutes = float(nums[1]) if len(nums) > 1 else 0.0
    seconds = float(nums[2]) if len(nums) > 2 else 0.0

    decimal = degrees + minutes / 60 + seconds / 3600
    return sign * decimal

# Create decimal latitude/longitude for mapping

df["lat_dd"] = df["latitude"].apply(dms_to_decimal)
df["lon_dd"] = df["longitude"].apply(dms_to_decimal)

# Remove rows with invalid coordinates
df = df.dropna(subset=["lat_dd", "lon_dd"]).reset_index(drop=True)

# %%
#  Build GeoDataFrame for cities and load Europe map

cities_gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df["lon_dd"], df["lat_dd"]),
    crs="EPSG:4326"    # WGS84 geographic coordinates (lat/lon)
)

world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
europe = world[world["continent"] == "Europe"].copy()

# Changing the coordinate system for nicer visualization

cities_gdf = cities_gdf.to_crs(epsg=3857)
europe = europe.to_crs(epsg=3857)

# Create HTML popup content

def fmt_int(x):
    """Format integers with thousands separator or 'n.a.'."""
    return f"{x:,.0f}" if pd.notna(x) else "n.a."

cities_gdf["popup_html"] = (
    "<b>City:</b> " + cities_gdf["City"].astype(str) +
    "<br><b>Country:</b> " + cities_gdf["Country"].astype(str) +
    "<br><b>Population:</b> " + cities_gdf["Population"].apply(fmt_int) +
    "<br><b>Average Monthly Salary (€):</b> " +
        cities_gdf["Average Monthly Salary"].apply(fmt_int) + " €" +
    "<br><b>Average Cost of Living (€):</b> " +
        cities_gdf["Average Cost of Living"].apply(fmt_int) + " €"
)

#  Map style and customisation

sns.set_theme(style="white")  # cleaner general style
pop_cmap = sns.color_palette("rocket_r", as_cmap=True)

# Base map: Europe polygons with a clean basemap
m = europe.explore(
    tiles="CartoDB positron",          # light basemap
    style_kwds={
        "fillColor": "#f7f7f7",        # light grey land
        "color": "#b0b0b0",            # thin grey borders
        "weight": 0.4
    },
    tooltip=False,
    popup=False,
    name="Europe"
)

cities_gdf.explore(
    m=m,
    tooltip=[
        "City",
        "Country",
        "Population",
        "Average Monthly Salary",
        "Average Cost of Living"
    ],                                   # information shown on hover
    marker_kwds={
        "radius": 7,                     # marker size
        "fillOpacity": 0.9,
    },
    name="Cities"
)
# Out:
# /var/folders/dc/jfb4p3vj5q9dcq1f9lcgzl5c0000gn/T/ipykernel_3772/3849995091.py:9: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af83b835368fa3c6bb3bf8ab2b575b91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af83b835368fa3c6bb3bf8ab2b575b91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af83b835368fa3c6bb3bf8ab2b575b91 = L.map(
#                 &quot;map_af83b835368fa3c6bb3bf8ab2b575b91&quot;,
#                 {
#                     center: [41.65189459350799, 1.4210854715202004e-14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_af83b835368fa3c6bb3bf8ab2b575b91);
#
#
#
#
#
#             var tile_layer_0fab0328af8290c869588a4c7ac49fbd = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0fab0328af8290c869588a4c7ac49fbd.addTo(map_af83b835368fa3c6bb3bf8ab2b575b91);
#
#
#             map_af83b835368fa3c6bb3bf8ab2b575b91.fitBounds(
#                 [[2.0533891870159806, -180.0], [81.2504, 180.00000000000003]],
#                 {}
#             );
#
#
#         function geo_json_f57fca91ba1c8804c1ef46a8f469467a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#b0b0b0&quot;, &quot;fillColor&quot;: &quot;#f7f7f7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 0.4};
#             }
#         }
#         function geo_json_f57fca91ba1c8804c1ef46a8f469467a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f57fca91ba1c8804c1ef46a8f469467a_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_f57fca91ba1c8804c1ef46a8f469467a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f57fca91ba1c8804c1ef46a8f469467a_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f57fca91ba1c8804c1ef46a8f469467a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f57fca91ba1c8804c1ef46a8f469467a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f57fca91ba1c8804c1ef46a8f469467a = L.geoJson(null, {
#                 onEachFeature: geo_json_f57fca91ba1c8804c1ef46a8f469467a_onEachFeature,
#
#                 style: geo_json_f57fca91ba1c8804c1ef46a8f469467a_styler,
#                 pointToLayer: geo_json_f57fca91ba1c8804c1ef46a8f469467a_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_f57fca91ba1c8804c1ef46a8f469467a_add (data) {
#             geo_json_f57fca91ba1c8804c1ef46a8f469467a
#                 .addData(data);
#         }
#             geo_json_f57fca91ba1c8804c1ef46a8f469467a_add({&quot;bbox&quot;: [-180.0, 2.0533891870159806, 180.00000000000003, 81.2504], &quot;features&quot;: [{&quot;bbox&quot;: [-180.0, 41.15141612402135, 180.00000000000003, 81.2504], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[180.00000000000003, 71.51571433
