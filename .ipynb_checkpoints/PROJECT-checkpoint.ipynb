# %% [markdown]
# # **Where should I live?** <br>
# ## Group Project of Programming for Data Science 2025/26 <br>
# Angelica Lamberti 20250999 <br>
# Samuel Nazzaro <br>
# Efe <br>
# Madeleine

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **1.  Data wrangling and analysis**

# %%
#Importing the data
data= pd.read_csv('city_data.csv', sep='|', header=1, parse_dates=['Last Data Update'])

print('Dimension of the data set:', data.shape) #The dataset has 86 rows and 14 columns
data.head()
# Out:
# Dimension of the data set: (86, 14)
#                 City  Population Density  Population  Working Age Population   \
# 0    Vienna, Austria               310.0     2983513                2018818.0
# 1  Salzburg, Austria               243.0      375489                 250472.0
# 2  Brussels, Belgium               681.0     3284548                2137425.0
# 3   Antwerp, Belgium               928.0     1139663                 723396.0
# 4      Gent, Belgium               552.0      645813                 417832.0
#
#    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 0                    20.1               10.2         55770.0
# 1                    20.3                3.0         66689.0
# 2                    27.5               10.7         62500.0
# 3                    27.7                6.2         57595.0
# 4                    24.8                NaN         53311.0
#
#    Days of very strong heat stress              Main Spoken Languages  \
# 0                                3  German, English, Turkish, Serbian
# 1                                0                             German
# 2                                3     French, Dutch, Arabic, English
# 3                                3              Dutch, French, Arabic
# 4                                2                      Dutch, French
#
#    Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 0                    2500                 1050                    2061
# 1                    3200                 1100                    2186
# 2                    3350                 1200                    1900
# 3                    2609                  900                    1953
# 4                    2400                  827                    1200
#
#    Average Price Groceries Last Data Update
# 0                    340.0       2024-06-15
# 1                      NaN       2023-11-03
# 2                      NaN       2023-04-22
# 3                      NaN       2024-08-09
# 4                    120.0       2023-07-17

# %% [markdown]
# ### **Exploratory Analysis**
# **Question 1** How did you handle missing values and duplicate records in the dataset?

# %%
data.info()
#We have 80 missing values for Average Price Groceries, 
#1 for Population Density, 
#1 for Working Age Population, 
#1 for Unemployment Rate, 
#1 for GDP per Capita, 
#1 for Main Spoken Languages
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             86 non-null     object
#  1   Population Density               85 non-null     float64
#  2   Population                       86 non-null     int64
#  3   Working Age Population           85 non-null     float64
#  4   Youth Dependency Ratio           86 non-null     float64
#  5   Unemployment Rate                85 non-null     float64
#  6   GDP per Capita                   85 non-null     float64
#  7   Days of very strong heat stress  86 non-null     int64
#  8   Main Spoken Languages            85 non-null     object
#  9   Average Monthly Salary           86 non-null     int64
#  10  Avgerage Rent Price              86 non-null     int64
#  11  Average Cost of Living           86 non-null     int64
#  12  Average Price Groceries          6 non-null      float64
#  13  Last Data Update                 86 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(5), object(2)
# memory usage: 9.5+ KB

# %% [markdown]
# Since the Average Price Groceries column has more than 70% of missing values, it's not very meaningful to consider it. We can drop it and for this purpose a copy of the data is created: all the changes will be done on that copy ('data_copy').

# %%
data_copy=data.drop('Average Price Groceries', axis=1)
data_copy
# Out:
#                   City  Population Density  Population  \
# 0      Vienna, Austria               310.0     2983513
# 1    Salzburg, Austria               243.0      375489
# 2    Brussels, Belgium               681.0     3284548
# 3     Antwerp, Belgium               928.0     1139663
# 4        Gent, Belgium               552.0      645813
# ..                 ...                 ...         ...
# 81   Stockholm, Sweden               334.0     2344124
# 82  Gothenburg, Sweden               245.0     1037675
# 83       Malmo, Sweden               368.0      680335
# 84     Ankara, Turkiye              1922.0     4843511
# 85      Adana, Turkiye               552.0     1074543
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 0                 2018818.0                    20.1               10.2
# 1                  250472.0                    20.3                3.0
# 2                 2137425.0                    27.5               10.7
# 3                  723396.0                    27.7                6.2
# 4                  417832.0                    24.8                NaN
# ..                      ...                     ...                ...
# 81                1534225.0                    28.5                6.2
# 82                 672152.0                    28.2                6.3
# 83                 436271.0                    29.4                9.2
# 84                3417691.0                    30.0               14.4
# 85                 718256.0                    37.8               12.2
#
#     GDP per Capita  Days of very strong heat stress  \
# 0          55770.0                                3
# 1          66689.0                                0
# 2          62500.0                                3
# 3          57595.0                                3
# 4          53311.0                                2
# ..             ...                              ...
# 81         70950.0                                0
# 82         49588.0                                0
# 83         44387.0                                0
# 84         38916.0                                3
# 85         19945.0                               59
#
#                 Main Spoken Languages  Average Monthly Salary  \
# 0   German, English, Turkish, Serbian                    2500
# 1                              German                    3200
# 2      French, Dutch, Arabic, English                    3350
# 3               Dutch, French, Arabic                    2609
# 4                       Dutch, French                    2400
# ..                                ...                     ...
# 81                   Swedish, English                    2700
# 82                   Swedish, English                    2500
# 83                   Swedish, English                    2400
# 84                            Turkish                     900
# 85                            Turkish                     750
#
#     Avgerage Rent Price  Average Cost of Living Last Data Update
# 0                  1050                    2061       2024-06-15
# 1                  1100                    2186       2023-11-03
# 2                  1200                    1900       2023-04-22
# 3                   900                    1953       2024-08-09
# 4                   827                    1200       2023-07-17
# ..                  ...                     ...              ...
# 81                 1400                    2300       2024-09-11
# 82                 1200                    2100       2023-03-10
# 83                 1100                    2000       2024-07-07
# 84                  450                     900       2023-06-08
# 85                  350                     800       2024-05-02
#
# [86 rows x 13 columns]

# %%
#Are there duplicate records?
data['City'].describe()
# Out:
# count                  86
# unique                 84
# top       Berlin. Germany
# freq                    2
# Name: City, dtype: object

# %%
data['City'].value_counts()
# Out:
# City
# Berlin. Germany           2
# Malaga, Spain             2
# Vienna, Austria           1
# Rotterdam, Netherlands    1
# The Hague, Netherlands    1
#                          ..
# Madrid, Spain             1
# Odense, Denmark           1
# Copenhagen, Denmark       1
# Hanover, Germany          1
# Adana, Turkiye            1
# Name: count, Length: 84, dtype: int64

# %% [markdown]
# 'Berlin, Germany' and 'Malaga, Spain' appear twice in the dataset! Are them duplicates info?

# %%
#Check that info are the same
data.set_index('City').loc['Berlin. Germany']
data.set_index('City').loc['Malaga, Spain']
# Out:
#                Population Density  Population  Working Age Population   \
# City
# Malaga, Spain               571.0      869096                 585608.0
# Malaga, Spain               571.0      869096                 585608.0
#
#                Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# City
# Malaga, Spain                    23.5               17.7         27694.0
# Malaga, Spain                    23.5               17.7         27694.0
#
#                Days of very strong heat stress Main Spoken Languages  \
# City
# Malaga, Spain                                0      Spanish, English
# Malaga, Spain                                0      Spanish, English
#
#                Average Monthly Salary  Avgerage Rent Price  \
# City
# Malaga, Spain                    2200                 1312
# Malaga, Spain                    2200                 1312
#
#                Average Cost of Living  Average Price Groceries  \
# City
# Malaga, Spain                    1400                      NaN
# Malaga, Spain                    1400                      NaN
#
#               Last Data Update
# City
# Malaga, Spain       2023-11-27
# Malaga, Spain       2023-11-27

# %% [markdown]
# Duplicates can be deleted from data_copy:

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#                   City  Population Density  Population  \
# 0      Vienna, Austria               310.0     2983513
# 1    Salzburg, Austria               243.0      375489
# 2    Brussels, Belgium               681.0     3284548
# 3     Antwerp, Belgium               928.0     1139663
# 4        Gent, Belgium               552.0      645813
# ..                 ...                 ...         ...
# 81   Stockholm, Sweden               334.0     2344124
# 82  Gothenburg, Sweden               245.0     1037675
# 83       Malmo, Sweden               368.0      680335
# 84     Ankara, Turkiye              1922.0     4843511
# 85      Adana, Turkiye               552.0     1074543
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 0                 2018818.0                    20.1               10.2
# 1                  250472.0                    20.3                3.0
# 2                 2137425.0                    27.5               10.7
# 3                  723396.0                    27.7                6.2
# 4                  417832.0                    24.8                NaN
# ..                      ...                     ...                ...
# 81                1534225.0                    28.5                6.2
# 82                 672152.0                    28.2                6.3
# 83                 436271.0                    29.4                9.2
# 84                3417691.0                    30.0               14.4
# 85                 718256.0                    37.8               12.2
#
#     GDP per Capita  Days of very strong heat stress  \
# 0          55770.0                                3
# 1          66689.0                                0
# 2          62500.0                                3
# 3          57595.0                                3
# 4          53311.0                                2
# ..             ...                              ...
# 81         70950.0                                0
# 82         49588.0                                0
# 83         44387.0                                0
# 84         38916.0                                3
# 85         19945.0                               59
#
#                 Main Spoken Languages  Average Monthly Salary  \
# 0   German, English, Turkish, Serbian                    2500
# 1                              German                    3200
# 2      French, Dutch, Arabic, English                    3350
# 3               Dutch, French, Arabic                    2609
# 4                       Dutch, French                    2400
# ..                                ...                     ...
# 81                   Swedish, English                    2700
# 82                   Swedish, English                    2500
# 83                   Swedish, English                    2400
# 84                            Turkish                     900
# 85                            Turkish                     750
#
#     Avgerage Rent Price  Average Cost of Living  Average Price Groceries  \
# 0                  1050                    2061                    340.0
# 1                  1100                    2186                      NaN
# 2                  1200                    1900                      NaN
# 3                   900                    1953                      NaN
# 4                   827                    1200                    120.0
# ..                  ...                     ...                      ...
# 81                 1400                    2300                      NaN
# 82                 1200                    2100                      NaN
# 83                 1100                    2000                      NaN
# 84                  450                     900                    309.0
# 85                  350                     800                      NaN
#
#    Last Data Update
# 0        2024-06-15
# 1        2023-11-03
# 2        2023-04-22
# 3        2024-08-09
# 4        2023-07-17
# ..              ...
# 81       2024-09-11
# 82       2023-03-10
# 83       2024-07-07
# 84       2023-06-08
# 85       2024-05-02
#
# [84 rows x 14 columns]

# %% [markdown]
# Since the 'City' columns contains 2 pieces of information, city and country, we want to split this column in 2 different columns: 1 for cities and the other for countries. In that way we can work on these information more easily.

# %% [markdown]
# **Question 2.a** Which country appears most frequently in the dataset? How many cities are associated with it?

# %%
data_copy = data_copy.rename(columns={'City': 'city&country'}) 
data_copy[['city', 'country']] = data_copy['city&country'].str.split(',', expand=True)

countries_count = data_copy['country'].value_counts()
countries_count
# Out:
# country
# Germany            9
# Spain              6
# Italy              6
# Netherlands        5
# United Kingdom     5
# Belgium            4
# Portugal           4
# Sweden             3
# Switzerland        3
# Poland             3
# Norway             3
# Hungary            3
# Austria            2
# Ireland            2
# Croatia            2
# Turkiye            2
# Czechia            2
# Bulgaria           2
# France             2
# Finland            2
# Denmark            2
# Slovenia           1
# Slovak Republic    1
# Romania            1
# Cyprus             1
# Greece             1
# Athens             1
# Malta              1
# Latvia             1
# Luxembourg         1
#  France            1
# Estonia            1
# Name: count, dtype: int64

# %% [markdown]
# Germany is the country that appears more frequently in the dataset, with a frequency of 9 times; so 9 cities are associated with Germany.

# %% [markdown]
# **Question 2.b** How many cities are present in total? How many are associated with Greece?

# %%
data['City'].describe()
#We can see that there are no more duplicates info
# Out:
# count                  84
# unique                 84
# top       Vienna, Austria
# freq                    1
# Name: City, dtype: object

# %%
data_copy.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   city&country                     86 non-null     object
#  1   Population Density               85 non-null     float64
#  2   Population                       86 non-null     int64
#  3   Working Age Population           85 non-null     float64
#  4   Youth Dependency Ratio           86 non-null     float64
#  5   Unemployment Rate                85 non-null     float64
#  6   GDP per Capita                   85 non-null     float64
#  7   Days of very strong heat stress  86 non-null     int64
#  8   Main Spoken Languages            85 non-null     object
#  9   Average Monthly Salary           86 non-null     int64
#  10  Avgerage Rent Price              86 non-null     int64
#  11  Average Cost of Living           86 non-null     int64
#  12  Last Data Update                 86 non-null     datetime64[ns]
#  13  city                             86 non-null     object
#  14  country                          83 non-null     object
# dtypes: datetime64[ns](1), float64(5), int64(5), object(4)
# memory usage: 10.2+ KB

# %%
city_list=data_copy['city'].tolist()
country_list=data_copy['country'].tolist()

# %% [markdown]
# There are some problems with the sintax: 'Athens' is in the country column and 'Greece' is in the city one.
# Furthermore we need to expand some rows where the separator in the city column was not a ','.

# %%
data_copy[data_copy['country'].isnull()]
#In line 12 we have a ';' as a separator, and in the line 15 we have a '.'
# Out:
#        city&country  Population Density  Population  Working Age Population   \
# 12   Lemesos;Cyprus               190.0      262238                 173906.0
# 15  Berlin. Germany               304.0     5303922                3481212.0
# 16  Berlin. Germany               304.0     5303922                3481212.0
#
#     Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 12                   23.06               11.2             NaN
# 15                   21.30                4.7         46548.0
# 16                   21.30                4.7         46548.0
#
#     Days of very strong heat stress             Main Spoken Languages  \
# 12                                0           Greek, English, Russian
# 15                                3  German, Turkish, Arabic, English
# 16                                3  German, Turkish, Arabic, English
#
#     Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 12                    2500                 1400                    2300
# 15                    3200                 1220                    2200
# 16                    3200                 1220                    2200
#
#    Last Data Update             city country
# 12       2023-08-14   Lemesos;Cyprus    None
# 15       2023-06-29  Berlin. Germany    None
# 16       2023-06-29  Berlin. Germany    None

# %%
line_12_element=data_copy.iloc[12,0]
line_15_element=data_copy.iloc[15,0]
data_copy[['city', 'country']].iloc[12] = line_12_element.split(';')
data_copy[['city', 'country']].iloc[15] = line_15_element.split('.')
data_copy=data_copy.set_index('city&country').drop('Berlin. Germany', axis=0)
data_copy
# Out:
# /var/folders/dc/jfb4p3vj5q9dcq1f9lcgzl5c0000gn/T/ipykernel_7107/1185207185.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data_copy[['city', 'country']].iloc[12] = line_12_element.split(';')
# /var/folders/dc/jfb4p3vj5q9dcq1f9lcgzl5c0000gn/T/ipykernel_7107/1185207185.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data_copy[['city', 'country']].iloc[15] = line_15_element.split('.')
#                     Population Density  Population  Working Age Population   \
# city&country
# Vienna, Austria                  310.0     2983513                2018818.0
# Salzburg, Austria                243.0      375489                 250472.0
# Brussels, Belgium                681.0     3284548                2137425.0
# Antwerp, Belgium                 928.0     1139663                 723396.0
# Gent, Belgium                    552.0      645813                 417832.0
# ...                                ...         ...                      ...
# Stockholm, Sweden                334.0     2344124                1534225.0
# Gothenburg, Sweden               245.0     1037675                 672152.0
# Malmo, Sweden                    368.0      680335                 436271.0
# Ankara, Turkiye                 1922.0     4843511                3417691.0
# Adana, Turkiye                   552.0     1074543                 718256.0
#
#                     Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# city&country
# Vienna, Austria                       20.1               10.2         55770.0
# Salzburg, Austria                     20.3                3.0         66689.0
# Brussels, Belgium                     27.5               10.7         62500.0
# Antwerp, Belgium                      27.7                6.2         57595.0
# Gent, Belgium                         24.8                NaN         53311.0
# ...                                    ...                ...             ...
# Stockholm, Sweden                     28.5                6.2         70950.0
# Gothenburg, Sweden                    28.2                6.3         49588.0
# Malmo, Sweden                         29.4                9.2         44387.0
# Ankara, Turkiye                       30.0               14.4         38916.0
# Adana, Turkiye                        37.8               12.2         19945.0
#
#                     Days of very strong heat stress  \
# city&country
# Vienna, Austria                                   3
# Salzburg, Austria                                 0
# Brussels, Belgium                                 3
# Antwerp, Belgium                                  3
# Gent, Belgium                                     2
# ...                                             ...
# Stockholm, Sweden                                 0
# Gothenburg, Sweden                                0
# Malmo, Sweden                                     0
# Ankara, Turkiye                                   3
# Adana, Turkiye                                   59
#
#                                 Main Spoken Languages  Average Monthly Salary  \
# city&country
# Vienna, Austria     German, English, Turkish, Serbian                    2500
# Salzburg, Austria                              German                    3200
# Brussels, Belgium      French, Dutch, Arabic, English                    3350
# Antwerp, Belgium                Dutch, French, Arabic                    2609
# Gent, Belgium                           Dutch, French                    2400
# ...                                               ...                     ...
# Stockholm, Sweden                    Swedish, English                    2700
# Gothenburg, Sweden                   Swedish, English                    2500
# Malmo, Sweden                        Swedish, English                    2400
# Ankara, Turkiye                               Turkish                     900
# Adana, Turkiye                                Turkish                     750
#
#                     Avgerage Rent Price  Average Cost of Living  \
# city&country
# Vienna, Austria                    1050                    2061
# Salzburg, Austria                  1100                    2186
# Brussels, Belgium                  1200                    1900
# Antwerp, Belgium                    900                    1953
# Gent, Belgium                       827                    1200
# ...                                 ...                     ...
# Stockholm, Sweden                  1400                    2300
# Gothenburg, Sweden                 1200                    2100
# Malmo, Sweden                      1100                    2000
# Ankara, Turkiye                     450                     900
# Adana, Turkiye                      350                     800
#
#                    Last Data Update        city   country
# city&country
# Vienna, Austria          2024-06-15      Vienna   Austria
# Salzburg, Austria        2023-11-03    Salzburg   Austria
# Brussels, Belgium        2023-04-22    Brussels   Belgium
# Antwerp, Belgium         2024-08-09     Antwerp   Belgium
# Gent, Belgium            2023-07-17        Gent   Belgium
# ...                             ...         ...       ...
# Stockholm, Sweden        2024-09-11   Stockholm    Sweden
# Gothenburg, Sweden       2023-03-10  Gothenburg    Sweden
# Malmo, Sweden            2024-07-07       Malmo    Sweden
# Ankara, Turkiye          2023-06-08      Ankara   Turkiye
# Adana, Turkiye           2024-05-02       Adana   Turkiye
#
# [84 rows x 14 columns]

# %%
columns=data_copy.columns.to_list()
data_copy = data_copy[columns[-2:] + columns[:-2]]
data_copy
#Putting the city and country columns as the first and second ones
# Out:
#                           city   country  Population Density  Population  \
# city&country
# Vienna, Austria         Vienna   Austria               310.0     2983513
# Salzburg, Austria     Salzburg   Austria               243.0      375489
# Brussels, Belgium     Brussels   Belgium               681.0     3284548
# Antwerp, Belgium       Antwerp   Belgium               928.0     1139663
# Gent, Belgium             Gent   Belgium               552.0      645813
# ...                        ...       ...                 ...         ...
# Stockholm, Sweden    Stockholm    Sweden               334.0     2344124
# Gothenburg, Sweden  Gothenburg    Sweden               245.0     1037675
# Malmo, Sweden            Malmo    Sweden               368.0      680335
# Ankara, Turkiye         Ankara   Turkiye              1922.0     4843511
# Adana, Turkiye           Adana   Turkiye               552.0     1074543
#
#                     Working Age Population   Youth Dependency Ratio  \
# city&country
# Vienna, Austria                   2018818.0                    20.1
# Salzburg, Austria                  250472.0                    20.3
# Brussels, Belgium                 2137425.0                    27.5
# Antwerp, Belgium                   723396.0                    27.7
# Gent, Belgium                      417832.0                    24.8
# ...                                     ...                     ...
# Stockholm, Sweden                 1534225.0                    28.5
# Gothenburg, Sweden                 672152.0                    28.2
# Malmo, Sweden                      436271.0                    29.4
# Ankara, Turkiye                   3417691.0                    30.0
# Adana, Turkiye                     718256.0                    37.8
#
#                     Unemployment Rate  GDP per Capita  \
# city&country
# Vienna, Austria                  10.2         55770.0
# Salzburg, Austria                 3.0         66689.0
# Brussels, Belgium                10.7         62500.0
# Antwerp, Belgium                  6.2         57595.0
# Gent, Belgium                     NaN         53311.0
# ...                               ...             ...
# Stockholm, Sweden                 6.2         70950.0
# Gothenburg, Sweden                6.3         49588.0
# Malmo, Sweden                     9.2         44387.0
# Ankara, Turkiye                  14.4         38916.0
# Adana, Turkiye                   12.2         19945.0
#
#                     Days of very strong heat stress  \
# city&country
# Vienna, Austria                                   3
# Salzburg, Austria                                 0
# Brussels, Belgium                                 3
# Antwerp, Belgium                                  3
# Gent, Belgium                                     2
# ...                                             ...
# Stockholm, Sweden                                 0
# Gothenburg, Sweden                                0
# Malmo, Sweden                                     0
# Ankara, Turkiye                                   3
# Adana, Turkiye                                   59
#
#                                 Main Spoken Languages  Average Monthly Salary  \
# city&country
# Vienna, Austria     German, English, Turkish, Serbian                    2500
# Salzburg, Austria                              German                    3200
# Brussels, Belgium      French, Dutch, Arabic, English                    3350
# Antwerp, Belgium                Dutch, French, Arabic                    2609
# Gent, Belgium                           Dutch, French                    2400
# ...                                               ...                     ...
# Stockholm, Sweden                    Swedish, English                    2700
# Gothenburg, Sweden                   Swedish, English                    2500
# Malmo, Sweden                        Swedish, English                    2400
# Ankara, Turkiye                               Turkish                     900
# Adana, Turkiye                                Turkish                     750
#
#                     Avgerage Rent Price  Average Cost of Living  \
# city&country
# Vienna, Austria                    1050                    2061
# Salzburg, Austria                  1100                    2186
# Brussels, Belgium                  1200                    1900
# Antwerp, Belgium                    900                    1953
# Gent, Belgium                       827                    1200
# ...                                 ...                     ...
# Stockholm, Sweden                  1400                    2300
# Gothenburg, Sweden                 1200                    2100
# Malmo, Sweden                      1100                    2000
# Ankara, Turkiye                     450                     900
# Adana, Turkiye                      350                     800
#
#                    Last Data Update
# city&country
# Vienna, Austria          2024-06-15
# Salzburg, Austria        2023-11-03
# Brussels, Belgium        2023-04-22
# Antwerp, Belgium         2024-08-09
# Gent, Belgium            2023-07-17
# ...                             ...
# Stockholm, Sweden        2024-09-11
# Gothenburg, Sweden       2023-03-10
# Malmo, Sweden            2024-07-07
# Ankara, Turkiye          2023-06-08
# Adana, Turkiye           2024-05-02
#
# [84 rows x 14 columns]

# %%
data_copy[data_copy['country']==' Athens']
#row index 43
temp=data_copy.iloc[43,0]
data_copy.iloc[43,0]=data_copy.iloc[43,1]
data_copy.iloc[43,1]=temp
data_copy.iloc[43,:]
#Now Athens and Greece are in the right place
# Out:
# city                                            Athens
# country                                         Greece
# Population Density                              1829.0
# Population                                     3530371
# Working Age Population                       2287174.0
# Youth Dependency Ratio                            22.0
# Unemployment Rate                                 17.2
# GDP per Capita                                 38580.0
# Days of very strong heat stress                     17
# Main Spoken Languages                   Greek, English
# Average Monthly Salary                            1050
# Avgerage Rent Price                                600
# Average Cost of Living                            1200
# Last Data Update                   2024-07-16 00:00:00
# Name: Greece, Athens, dtype: object

# %%
cities_sum = data_copy['city'].value_counts().sum()
print('In total there are ', cities_sum, 'cities')

cities_count=data_copy['country'].value_counts()
print(cities_count)
# Out:
# In total there are  84 cities
# country
#  Germany            9
#  Spain              6
#  Italy              6
#  Netherlands        5
#  United Kingdom     5
#  Belgium            4
#  Portugal           4
#  Sweden             3
#  Switzerland        3
#  Poland             3
#  Norway             3
#  Hungary            3
#  Austria            2
#  Ireland            2
#  Croatia            2
#  Turkiye            2
#  Czechia            2
#  Bulgaria           2
#  France             2
#  Finland            2
#  Denmark            2
#  Slovenia           1
#  Slovak Republic    1
#  Romania            1
#  Cyprus             1
#  Greece             1
# Greece              1
#  Malta              1
#  Latvia             1
#  Luxembourg         1
#   France            1
#  Estonia            1
# Name: count, dtype: int64

# %% [markdown]
# 84 cities are present in total. 2 cities are associated with Greece: Athens and Zagreb

# %%
data_copy.set_index('country', inplace=True)
data_copy.index
# Out:
# Index([        ' Austria',         ' Austria',         ' Belgium',
#                ' Belgium',         ' Belgium',         ' Belgium',
#               ' Bulgaria',        ' Bulgaria',     ' Switzerland',
#            ' Switzerland',     ' Switzerland',          ' Cyprus',
#                      None,         ' Czechia',         ' Czechia',
#                ' Germany',         ' Germany',         ' Germany',
#                ' Germany',         ' Germany',         ' Germany',
#                ' Germany',         ' Germany',         ' Germany',
#                ' Denmark',         ' Denmark',           ' Spain',
#                  ' Spain',           ' Spain',           ' Spain',
#                  ' Spain',           ' Spain',         ' Estonia',
#                ' Finland',         ' Finland',          ' France',
#                '  France',          ' France',  ' United Kingdom',
#         ' United Kingdom',  ' United Kingdom',  ' United Kingdom',
#         ' United Kingdom',           'Greece',          ' Greece',
#                ' Croatia',         ' Croatia',         ' Hungary',
#                ' Hungary',         ' Hungary',         ' Ireland',
#                ' Ireland',           ' Italy',           ' Italy',
#                  ' Italy',           ' Italy',           ' Italy',
#                  ' Italy',      ' Luxembourg',          ' Latvia',
#                  ' Malta',     ' Netherlands',     ' Netherlands',
#            ' Netherlands',     ' Netherlands',     ' Netherlands',
#                 ' Norway',          ' Norway',          ' Norway',
#                 ' Poland',          ' Poland',          ' Poland',
#               ' Portugal',        ' Portugal',        ' Portugal',
#               ' Portugal',         ' Romania', ' Slovak Republic',
#               ' Slovenia',          ' Sweden',          ' Sweden',
#                 ' Sweden',         ' Turkiye',         ' Turkiye'],
#       dtype='object', name='country')

# %% [markdown]
# **Question 2.c** Which is the least spoken language in the dataset? Which are the top 3 most spoken languages?

# %%
languages_count=data_copy['Main Spoken Languages'].str.split(', ').explode().value_counts()
languages_count
#I create a list with all the main spoken languages togheter and then I can count them
# Out:
# Main Spoken Languages
# English              46
# German               13
# French               10
# Turkish               9
# Dutch                 9
# Italian               6
# Spanish               5
# Swedish               4
# Polish                4
# Greek                 4
# Portuguese            4
# Hungarian             3
# Russian               3
# Norwegian             3
# Croatian              2
# Urdu                  2
# Irish Gaelic          2
# Finnish               2
# Danish                2
# Czech                 2
# Bulgarian             2
# Arabic                2
# Maltese               1
# Latvian               1
# Luxembourgish         1
# Slovak                1
# Romanian              1
#   Arabic              1
# Scots Gaelic          1
# Scots                 1
# Bengali               1
# Estonian              1
# Spanish;Valencian     1
# Catalan               1
# Serbian               1
# Slovene               1
# Name: count, dtype: int64

# %% [markdown]
# The top 3 most spoken languages are:
# 1. English (46)
# 2. German (14)
# 3. Turkish (10)
# 3. France (10)
#
# The least spoken languages are: Sloven, Maltese, Latvian, Luxembourgish, Slovak, Romanian, Scots Gaelic, Scots, Bengali, Estonian, Valencian, Catalan and Serbian.

# %% [markdown]
# **Question 3.a** Entries uploaded before April 2023 need to be updated. Which cities would require an update?

# %%
begin_April_23=pd.to_datetime('2023-04-1')
filter=data_copy[data_copy['Last Data Update']< begin_April_23]
filter['city']
#Basel, Munich, Frankfurt am Main, Lyon, Venice and Gothenburg need an update
# Out:
# country
# Switzerland                Basel
# Germany                   Munich
# Germany        Frankfurt am Main
#  France                     Lyon
# Italy                     Venice
# Sweden                Gothenburg
# Name: city, dtype: object

# %% [markdown]
# **Question 3.b** How many days ago was the last update? On what day, month, and year did it occur?

# %%
date_today= pd.Timestamp('today').normalize()
last_update=max(data_copy['Last Data Update'])
days= (date_today-last_update).days
print('The last update was', days, 'days ago')
print('The last update was on', last_update)
# Out:
# The last update was 345 days ago
# The last update was on 2024-12-12 00:00:00

# %% [markdown]
# **Question 4.a** How are the Unemployment Rate and GDP per Capita distributed and related? What does this relationship suggest? Provide a visual representation.

# %%
unemployment_rate=data_copy['Unemployment Rate']
GDP_per_capita=data_copy['GDP per Capita']
unemployment_rate.mode() 
GDP_per_capita.mode()
# Out:
# 0    27694.0
# 1    46226.0
# Name: GDP per Capita, dtype: float64

# %%
#How are Unemployement Rate and GDP per Capita distributed?
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.histplot(unemployment_rate, kde=True, color='skyblue')
plt.title('Distribution of Unemployment Rate')

plt.subplot(1,2,2)
sns.histplot(GDP_per_capita, kde=True, color='lightgreen')
plt.title('Distribution of GDP per Capita')

plt.tight_layout()
plt.show()

# %%
#Relationship between GDP per Capita and Unemployment Rate
plt.figure(figsize=(7,5))
sns.scatterplot(data=data_copy, x='GDP per Capita', y='Unemployment Rate')
sns.regplot(data=data_copy, x='GDP per Capita', y= 'Unemployment Rate', scatter=False, color='red')
plt.title('Relationship between GDP per Capita and Unemployment Rate')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 3
#       1 #Relationship between GDP per Capita and Unemployment Rate
#       2 plt.figure(figsize=(7,5))
# ----> 3 sns.scatterplot(data=data_copy, x='GDP per Capita', y='Unemployment Rate')
#       4 plt.title('Relationship between GDP per Capita and Unemployment Rate')
#       5 plt.show()
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/seaborn/relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/seaborn/relational.py:404, in _ScatterPlotter.plot(self, ax, kws)
#     400 def plot(self, ax, kws):
#     401
#     402     # --- Determine the visual attributes of the plot
# --> 404     data = self.comp_data.dropna()
#     405     if data.empty:
#     406         return
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/seaborn/_base.py:1007, in VectorPlotter.comp_data(self)
#    1005         else:
#    1006             comp_col = pd.Series(dtype=float, name=var)
# -> 1007         comp_data.insert(0, var, comp_col)
#    1009     self._comp_data = comp_data
#    1011 return self._comp_data
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/frame.py:5178, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    5175 elif isinstance(value, DataFrame):
#    5176     value = value.iloc[:, 0]
# -> 5178 value, refs = self._sanitize_column(value)
#    5179 self._mgr.insert(loc, column, value, refs=refs)
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/frame.py:5270, in DataFrame._sanitize_column(self, value)
#    5268     if not isinstance(value, Series):
#    5269         value = Series(value)
# -> 5270     return _reindex_for_setitem(value, self.index)
#    5272 if is_list_like(value):
#    5273     com.require_length_match(value, self.index)
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/frame.py:12699, in _reindex_for_setitem(value, index)
#   12695 except ValueError as err:
#   12696     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#   12697     if not value.index.is_unique:
#   12698         # duplicate axis
# > 12699         raise err
#   12701     raise TypeError(
#   12702         "incompatible index of inserted column with frame index"
#   12703     ) from err
#   12704 return reindexed_value, None
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/frame.py:12694, in _reindex_for_setitem(value, index)
#   12692 # GH#4107
#   12693 try:
# > 12694     reindexed_value = value.reindex(index)._values
#   12695 except ValueError as err:
#   12696     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#   12697     if not value.index.is_unique:
#   12698         # duplicate axis
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/series.py:5164, in Series.reindex(self, index, axis, method, copy, level, fill_value, limit, tolerance)
#    5147 @doc(
#    5148     NDFrame.reindex,  # type: ignore[has-type]
#    5149     klass=_shared_doc_kwargs["klass"],
#    (...)   5162     tolerance=None,
#    5163 ) -> Series:
# -> 5164     return super().reindex(
#    5165         index=index,
#    5166         method=method,
#    5167         copy=copy,
#    5168         level=level,
#    5169         fill_value=fill_value,
#    5170         limit=limit,
#    5171         tolerance=tolerance,
#    5172     )
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/generic.py:5629, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5626     return self._reindex_multi(axes, copy, fill_value)
#    5628 # perform the reindex on the axes
# -> 5629 return self._reindex_axes(
#    5630     axes, level, limit, tolerance, method, fill_value, copy
#    5631 ).__finalize__(self, method="reindex")
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/generic.py:5652, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5649     continue
#    5651 ax = self._get_axis(a)
# -> 5652 new_index, indexer = ax.reindex(
#    5653     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5654 )
#    5656 axis = self._get_axis_number(a)
#    5657 obj = obj._reindex_with_indexers(
#    5658     {axis: [new_index, indexer]},
#    5659     fill_value=fill_value,
#    5660     copy=copy,
#    5661     allow_dups=False,
#    5662 )
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/indexes/base.py:4436, in Index.reindex(self, target, method, level, limit, tolerance)
#    4433     raise ValueError("cannot handle a non-unique multi-index!")
#    4434 elif not self.is_unique:
#    4435     # GH#42568
# -> 4436     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4437 else:
#    4438     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
#b) Which are the top 5 cities with the largest difference between the Average Monthly Salary and Average Cost of Living? 
# What about the top 5 countries with the smallest average difference? Show these results with meaningful visualizations. TO DO

# %%
#c) Which is the best city for someone seeking:
#an average monthly salary above €2000,
#a cost of living below or equal to €1600, and
#a country suitable for starting a family (with a relatively larger youth population)? TO DO

# %%
#5. What are three additional insights you find meaningful when comparing the given cities? TO DO

# %%
#2 INTRERACTIVE MAP
