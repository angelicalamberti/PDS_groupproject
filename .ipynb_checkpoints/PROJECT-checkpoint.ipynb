# %% [markdown]
# # <span style= 'color: green'> **Where should I live?** </span> <br>
# ## Leveraging Data to Optimize Quality of Life Choices
# ### Group Project of Programming for Data Science 2025/26 <br>
# Angelica Lamberti 20250999 <br>
# Samuel Nazzaro <br>
# Efe <br>
# Maddleine

# %% [markdown]
#  <span style= 'color: red'>**Introduction** </span> <br> In the wake of increasing mobility across Europe, fueled by remote work, international education, and shifting social and economic priorities, there has been growing demand for tools that help citizens make better-informed decisions about where to live. <br>
#  <span style= 'color: red'> **Objectives** </span> <br>
# -Design a tool that translates complex country-level data into clear, actionable insights for everyday people: students seeking affordable education, professionals looking for better work-life balance, retirees interested in safety and healthcare, and more. <br>
# -Simplify this decision-making process by analyzing key characteristics of European countries, such as cost of living, safety, and employment. Through exploratory analysis, visualizations, and interpretable insights, the goal is to build a framework that empowers users to evaluate which countries align best with their personal values and life goals.

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## <span style= 'color: blue'> 1.  Data wrangling and analysis </span>

# %%
#Importing the data
data= pd.read_csv('city_data.csv', sep='|', header=1, parse_dates=['Last Data Update'])

print('Dimension of the data set:', data.shape) #The dataset has 86 rows and 14 columns
data.head()
# Out:
# Dimension of the data set: (86, 14)
#                 City  Population Density  Population  Working Age Population   \
# 0    Vienna, Austria               310.0     2983513                2018818.0
# 1  Salzburg, Austria               243.0      375489                 250472.0
# 2  Brussels, Belgium               681.0     3284548                2137425.0
# 3   Antwerp, Belgium               928.0     1139663                 723396.0
# 4      Gent, Belgium               552.0      645813                 417832.0
#
#    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 0                    20.1               10.2         55770.0
# 1                    20.3                3.0         66689.0
# 2                    27.5               10.7         62500.0
# 3                    27.7                6.2         57595.0
# 4                    24.8                NaN         53311.0
#
#    Days of very strong heat stress              Main Spoken Languages  \
# 0                                3  German, English, Turkish, Serbian
# 1                                0                             German
# 2                                3     French, Dutch, Arabic, English
# 3                                3              Dutch, French, Arabic
# 4                                2                      Dutch, French
#
#    Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 0                    2500                 1050                    2061
# 1                    3200                 1100                    2186
# 2                    3350                 1200                    1900
# 3                    2609                  900                    1953
# 4                    2400                  827                    1200
#
#    Average Price Groceries Last Data Update
# 0                    340.0       2024-06-15
# 1                      NaN       2023-11-03
# 2                      NaN       2023-04-22
# 3                      NaN       2024-08-09
# 4                    120.0       2023-07-17

# %% [markdown]
# ### **Exploratory Analysis**
# **Question 1** How did you handle missing values and duplicate records in the dataset?

# %%
data.info()
#We have 80 missing values for Average Price Groceries, 
#1 for Population Density, 
#1 for Working Age Population, 
#1 for Unemployment Rate, 
#1 for GDP per Capita, 
#1 for Main Spoken Languages
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             86 non-null     object
#  1   Population Density               85 non-null     float64
#  2   Population                       86 non-null     int64
#  3   Working Age Population           85 non-null     float64
#  4   Youth Dependency Ratio           86 non-null     float64
#  5   Unemployment Rate                85 non-null     float64
#  6   GDP per Capita                   85 non-null     float64
#  7   Days of very strong heat stress  86 non-null     int64
#  8   Main Spoken Languages            85 non-null     object
#  9   Average Monthly Salary           86 non-null     int64
#  10  Avgerage Rent Price              86 non-null     int64
#  11  Average Cost of Living           86 non-null     int64
#  12  Average Price Groceries          6 non-null      float64
#  13  Last Data Update                 86 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(5), object(2)
# memory usage: 9.5+ KB

# %% [markdown]
# Since the Average Price Groceries column contains more than 90% missing values, it provides limited analytical value. Therefore, this variable will be excluded from further analysis. To preserve the integrity of the original dataset, a copy—named data_copy—is created, and all the changes will be applied to this duplicate.

# %%
data_copy=data.drop('Average Price Groceries', axis=1)
data_copy
# Out:
#                   City  Population Density  Population  \
# 0      Vienna, Austria               310.0     2983513
# 1    Salzburg, Austria               243.0      375489
# 2    Brussels, Belgium               681.0     3284548
# 3     Antwerp, Belgium               928.0     1139663
# 4        Gent, Belgium               552.0      645813
# ..                 ...                 ...         ...
# 81   Stockholm, Sweden               334.0     2344124
# 82  Gothenburg, Sweden               245.0     1037675
# 83       Malmo, Sweden               368.0      680335
# 84     Ankara, Turkiye              1922.0     4843511
# 85      Adana, Turkiye               552.0     1074543
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 0                 2018818.0                    20.1               10.2
# 1                  250472.0                    20.3                3.0
# 2                 2137425.0                    27.5               10.7
# 3                  723396.0                    27.7                6.2
# 4                  417832.0                    24.8                NaN
# ..                      ...                     ...                ...
# 81                1534225.0                    28.5                6.2
# 82                 672152.0                    28.2                6.3
# 83                 436271.0                    29.4                9.2
# 84                3417691.0                    30.0               14.4
# 85                 718256.0                    37.8               12.2
#
#     GDP per Capita  Days of very strong heat stress  \
# 0          55770.0                                3
# 1          66689.0                                0
# 2          62500.0                                3
# 3          57595.0                                3
# 4          53311.0                                2
# ..             ...                              ...
# 81         70950.0                                0
# 82         49588.0                                0
# 83         44387.0                                0
# 84         38916.0                                3
# 85         19945.0                               59
#
#                 Main Spoken Languages  Average Monthly Salary  \
# 0   German, English, Turkish, Serbian                    2500
# 1                              German                    3200
# 2      French, Dutch, Arabic, English                    3350
# 3               Dutch, French, Arabic                    2609
# 4                       Dutch, French                    2400
# ..                                ...                     ...
# 81                   Swedish, English                    2700
# 82                   Swedish, English                    2500
# 83                   Swedish, English                    2400
# 84                            Turkish                     900
# 85                            Turkish                     750
#
#     Avgerage Rent Price  Average Cost of Living Last Data Update
# 0                  1050                    2061       2024-06-15
# 1                  1100                    2186       2023-11-03
# 2                  1200                    1900       2023-04-22
# 3                   900                    1953       2024-08-09
# 4                   827                    1200       2023-07-17
# ..                  ...                     ...              ...
# 81                 1400                    2300       2024-09-11
# 82                 1200                    2100       2023-03-10
# 83                 1100                    2000       2024-07-07
# 84                  450                     900       2023-06-08
# 85                  350                     800       2024-05-02
#
# [86 rows x 13 columns]

# %%
#Are there duplicate records?
data['City'].describe()
# Out:
# count                  86
# unique                 84
# top       Berlin. Germany
# freq                    2
# Name: City, dtype: object

# %%
data['City'].value_counts()
# Out:
# City
# Berlin. Germany           2
# Malaga, Spain             2
# Vienna, Austria           1
# Rotterdam, Netherlands    1
# The Hague, Netherlands    1
#                          ..
# Madrid, Spain             1
# Odense, Denmark           1
# Copenhagen, Denmark       1
# Hanover, Germany          1
# Adana, Turkiye            1
# Name: count, Length: 84, dtype: int64

# %% [markdown]
# The entries “Berlin, Germany” and “Malaga, Spain” appear twice in the dataset, suggesting that they may represent duplicate records. The next step is to check that info are actually the same.

# %%
data.set_index('City').loc['Berlin. Germany']
data.set_index('City').loc['Malaga, Spain']
# Out:
#                Population Density  Population  Working Age Population   \
# City
# Malaga, Spain               571.0      869096                 585608.0
# Malaga, Spain               571.0      869096                 585608.0
#
#                Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# City
# Malaga, Spain                    23.5               17.7         27694.0
# Malaga, Spain                    23.5               17.7         27694.0
#
#                Days of very strong heat stress Main Spoken Languages  \
# City
# Malaga, Spain                                0      Spanish, English
# Malaga, Spain                                0      Spanish, English
#
#                Average Monthly Salary  Avgerage Rent Price  \
# City
# Malaga, Spain                    2200                 1312
# Malaga, Spain                    2200                 1312
#
#                Average Cost of Living  Average Price Groceries  \
# City
# Malaga, Spain                    1400                      NaN
# Malaga, Spain                    1400                      NaN
#
#               Last Data Update
# City
# Malaga, Spain       2023-11-27
# Malaga, Spain       2023-11-27

# %% [markdown]
# Duplicates can be deleted from data_copy:

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#                   City  Population Density  Population  \
# 0      Vienna, Austria               310.0     2983513
# 1    Salzburg, Austria               243.0      375489
# 2    Brussels, Belgium               681.0     3284548
# 3     Antwerp, Belgium               928.0     1139663
# 4        Gent, Belgium               552.0      645813
# ..                 ...                 ...         ...
# 81   Stockholm, Sweden               334.0     2344124
# 82  Gothenburg, Sweden               245.0     1037675
# 83       Malmo, Sweden               368.0      680335
# 84     Ankara, Turkiye              1922.0     4843511
# 85      Adana, Turkiye               552.0     1074543
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 0                 2018818.0                    20.1               10.2
# 1                  250472.0                    20.3                3.0
# 2                 2137425.0                    27.5               10.7
# 3                  723396.0                    27.7                6.2
# 4                  417832.0                    24.8                NaN
# ..                      ...                     ...                ...
# 81                1534225.0                    28.5                6.2
# 82                 672152.0                    28.2                6.3
# 83                 436271.0                    29.4                9.2
# 84                3417691.0                    30.0               14.4
# 85                 718256.0                    37.8               12.2
#
#     GDP per Capita  Days of very strong heat stress  \
# 0          55770.0                                3
# 1          66689.0                                0
# 2          62500.0                                3
# 3          57595.0                                3
# 4          53311.0                                2
# ..             ...                              ...
# 81         70950.0                                0
# 82         49588.0                                0
# 83         44387.0                                0
# 84         38916.0                                3
# 85         19945.0                               59
#
#                 Main Spoken Languages  Average Monthly Salary  \
# 0   German, English, Turkish, Serbian                    2500
# 1                              German                    3200
# 2      French, Dutch, Arabic, English                    3350
# 3               Dutch, French, Arabic                    2609
# 4                       Dutch, French                    2400
# ..                                ...                     ...
# 81                   Swedish, English                    2700
# 82                   Swedish, English                    2500
# 83                   Swedish, English                    2400
# 84                            Turkish                     900
# 85                            Turkish                     750
#
#     Avgerage Rent Price  Average Cost of Living  Average Price Groceries  \
# 0                  1050                    2061                    340.0
# 1                  1100                    2186                      NaN
# 2                  1200                    1900                      NaN
# 3                   900                    1953                      NaN
# 4                   827                    1200                    120.0
# ..                  ...                     ...                      ...
# 81                 1400                    2300                      NaN
# 82                 1200                    2100                      NaN
# 83                 1100                    2000                      NaN
# 84                  450                     900                    309.0
# 85                  350                     800                      NaN
#
#    Last Data Update
# 0        2024-06-15
# 1        2023-11-03
# 2        2023-04-22
# 3        2024-08-09
# 4        2023-07-17
# ..              ...
# 81       2024-09-11
# 82       2023-03-10
# 83       2024-07-07
# 84       2023-06-08
# 85       2024-05-02
#
# [84 rows x 14 columns]

# %% [markdown]
# Since the 'City' columns contains 2 pieces of information, city and country, we want to split this column in 2 different columns: 1 for cities and the other for countries. In that way we can work on these information more easily.

# %% [markdown]
# **Question 2.a** Which country appears most frequently in the dataset? How many cities are associated with it?

# %%
data_copy = data_copy.rename(columns={'City': 'city&country'}) 
data_copy[['city', 'country']] = data_copy['city&country'].str.split(',', expand=True)

countries_count = data_copy['country'].value_counts()
countries_count
# Out:
# country
# Germany            9
# Spain              6
# Italy              6
# Netherlands        5
# United Kingdom     5
# Belgium            4
# Portugal           4
# Sweden             3
# Switzerland        3
# Poland             3
# Norway             3
# Hungary            3
# Austria            2
# Ireland            2
# Croatia            2
# Turkiye            2
# Czechia            2
# Bulgaria           2
# France             2
# Finland            2
# Denmark            2
# Slovenia           1
# Slovak Republic    1
# Romania            1
# Cyprus             1
# Greece             1
# Athens             1
# Malta              1
# Latvia             1
# Luxembourg         1
#  France            1
# Estonia            1
# Name: count, dtype: int64

# %% [markdown]
# Germany is the most frequently represented country in the dataset, appearing 9 times. This indicates that 9 different cities are associated with Germany.

# %%
data_copy[data_copy['country']==' Germany']
# Out:
#                   city&country  Population Density  Population  \
# 17            Hamburg, Germany               461.0     3315036
# 18             Munich, Germany               529.0     2907752
# 19            Cologne, Germany              1233.0     2002550
# 20  Frankfurt am Main, Germany               631.0     2710501
# 21          Stuttgart, Germany               763.0     2787449
# 22            Leipzig, Germany               263.0     1043613
# 23            Dresden, Germany               231.0     1343213
# 24         Dusseldorf, Germany              1295.0     1554077
# 25            Hanover, Germany               444.0     1316467
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 17                2181857.0                    21.5                3.2
# 18                1955041.0                    21.1                2.1
# 19                1335299.0                    20.8                3.9
# 20                1791435.0                    22.0                3.2
# 21                1843613.0                    21.2                2.5
# 22                 662617.0                    21.4                4.3
# 23                 818095.0                    23.0                3.8
# 24                      NaN                    21.4                3.3
# 25                 854349.0                    21.0                4.0
#
#     GDP per Capita  Days of very strong heat stress     Main Spoken Languages  \
# 17         61058.0                                0  German, English, Turkish
# 18         83965.0                                1           German, English
# 19         60310.0                                3  German, English, Turkish
# 20         69372.0                                6           German, English
# 21         67644.0                                3           German, Turkish
# 22         41097.0                                3                    German
# 23         39767.0                                0                    German
# 24         71238.0                                3                       NaN
# 25         54827.0                                2                    German
#
#     Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 17                    3500                 1100                    2100
# 18                    3540                 1500                    2550
# 19                    3200                 1030                    2000
# 20                    3800                 1300                    2350
# 21                    3300                 1300                    2300
# 22                    2800                  800                    1600
# 23                    3050                  800                    1530
# 24                    3200                 1100                    2050
# 25                    2800                  900                    1800
#
#    Last Data Update               city   country
# 17       2024-07-10            Hamburg   Germany
# 18       2023-03-16             Munich   Germany
# 19       2024-11-23            Cologne   Germany
# 20       2023-02-04  Frankfurt am Main   Germany
# 21       2024-05-19          Stuttgart   Germany
# 22       2023-07-30            Leipzig   Germany
# 23       2023-08-01            Dresden   Germany
# 24       2024-01-15         Dusseldorf   Germany
# 25       2023-10-07            Hanover   Germany

# %% [markdown]
# **Question 2.b** How many cities are present in total? How many are associated with Greece?

# %%
data['City'].describe()
#There are no more duplicates info
# Out:
# count                  84
# unique                 84
# top       Vienna, Austria
# freq                    1
# Name: City, dtype: object

# %%
data_copy.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   city&country                     86 non-null     object
#  1   Population Density               85 non-null     float64
#  2   Population                       86 non-null     int64
#  3   Working Age Population           85 non-null     float64
#  4   Youth Dependency Ratio           86 non-null     float64
#  5   Unemployment Rate                85 non-null     float64
#  6   GDP per Capita                   85 non-null     float64
#  7   Days of very strong heat stress  86 non-null     int64
#  8   Main Spoken Languages            85 non-null     object
#  9   Average Monthly Salary           86 non-null     int64
#  10  Avgerage Rent Price              86 non-null     int64
#  11  Average Cost of Living           86 non-null     int64
#  12  Last Data Update                 86 non-null     datetime64[ns]
#  13  city                             86 non-null     object
#  14  country                          83 non-null     object
# dtypes: datetime64[ns](1), float64(5), int64(5), object(4)
# memory usage: 10.2+ KB

# %%
city_list=data_copy['city'].tolist()
country_list=data_copy['country'].tolist()

# %% [markdown]
# There are some inconsistencies in the dataset’s syntax: “Athens” appears in the Country column, while “Greece” is incorrectly placed in the City column. In addition, certain rows need to be expanded because the separator used in the City column was not a comma.

# %%
data_copy[data_copy['country'].isnull()]
#In line 12 we have a ';' as a separator, and in the line 15 we have a '.'
# Out:
#        city&country  Population Density  Population  Working Age Population   \
# 12   Lemesos;Cyprus               190.0      262238                 173906.0
# 15  Berlin. Germany               304.0     5303922                3481212.0
# 16  Berlin. Germany               304.0     5303922                3481212.0
#
#     Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 12                   23.06               11.2             NaN
# 15                   21.30                4.7         46548.0
# 16                   21.30                4.7         46548.0
#
#     Days of very strong heat stress             Main Spoken Languages  \
# 12                                0           Greek, English, Russian
# 15                                3  German, Turkish, Arabic, English
# 16                                3  German, Turkish, Arabic, English
#
#     Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 12                    2500                 1400                    2300
# 15                    3200                 1220                    2200
# 16                    3200                 1220                    2200
#
#    Last Data Update             city country
# 12       2023-08-14   Lemesos;Cyprus    None
# 15       2023-06-29  Berlin. Germany    None
# 16       2023-06-29  Berlin. Germany    None

# %%
line_12_element=data_copy.iloc[12,0]
line_15_element=data_copy.iloc[15,0]
data_copy[['city', 'country']].iloc[12] = line_12_element.split(';')
data_copy[['city', 'country']].iloc[15] = line_15_element.split('.')
data_copy=data_copy.set_index('city&country').drop('Berlin. Germany', axis=0)
data_copy
# Out:
# /var/folders/dc/jfb4p3vj5q9dcq1f9lcgzl5c0000gn/T/ipykernel_15050/1185207185.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data_copy[['city', 'country']].iloc[12] = line_12_element.split(';')
# /var/folders/dc/jfb4p3vj5q9dcq1f9lcgzl5c0000gn/T/ipykernel_15050/1185207185.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data_copy[['city', 'country']].iloc[15] = line_15_element.split('.')
#                     Population Density  Population  Working Age Population   \
# city&country
# Vienna, Austria                  310.0     2983513                2018818.0
# Salzburg, Austria                243.0      375489                 250472.0
# Brussels, Belgium                681.0     3284548                2137425.0
# Antwerp, Belgium                 928.0     1139663                 723396.0
# Gent, Belgium                    552.0      645813                 417832.0
# ...                                ...         ...                      ...
# Stockholm, Sweden                334.0     2344124                1534225.0
# Gothenburg, Sweden               245.0     1037675                 672152.0
# Malmo, Sweden                    368.0      680335                 436271.0
# Ankara, Turkiye                 1922.0     4843511                3417691.0
# Adana, Turkiye                   552.0     1074543                 718256.0
#
#                     Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# city&country
# Vienna, Austria                       20.1               10.2         55770.0
# Salzburg, Austria                     20.3                3.0         66689.0
# Brussels, Belgium                     27.5               10.7         62500.0
# Antwerp, Belgium                      27.7                6.2         57595.0
# Gent, Belgium                         24.8                NaN         53311.0
# ...                                    ...                ...             ...
# Stockholm, Sweden                     28.5                6.2         70950.0
# Gothenburg, Sweden                    28.2                6.3         49588.0
# Malmo, Sweden                         29.4                9.2         44387.0
# Ankara, Turkiye                       30.0               14.4         38916.0
# Adana, Turkiye                        37.8               12.2         19945.0
#
#                     Days of very strong heat stress  \
# city&country
# Vienna, Austria                                   3
# Salzburg, Austria                                 0
# Brussels, Belgium                                 3
# Antwerp, Belgium                                  3
# Gent, Belgium                                     2
# ...                                             ...
# Stockholm, Sweden                                 0
# Gothenburg, Sweden                                0
# Malmo, Sweden                                     0
# Ankara, Turkiye                                   3
# Adana, Turkiye                                   59
#
#                                 Main Spoken Languages  Average Monthly Salary  \
# city&country
# Vienna, Austria     German, English, Turkish, Serbian                    2500
# Salzburg, Austria                              German                    3200
# Brussels, Belgium      French, Dutch, Arabic, English                    3350
# Antwerp, Belgium                Dutch, French, Arabic                    2609
# Gent, Belgium                           Dutch, French                    2400
# ...                                               ...                     ...
# Stockholm, Sweden                    Swedish, English                    2700
# Gothenburg, Sweden                   Swedish, English                    2500
# Malmo, Sweden                        Swedish, English                    2400
# Ankara, Turkiye                               Turkish                     900
# Adana, Turkiye                                Turkish                     750
#
#                     Avgerage Rent Price  Average Cost of Living  \
# city&country
# Vienna, Austria                    1050                    2061
# Salzburg, Austria                  1100                    2186
# Brussels, Belgium                  1200                    1900
# Antwerp, Belgium                    900                    1953
# Gent, Belgium                       827                    1200
# ...                                 ...                     ...
# Stockholm, Sweden                  1400                    2300
# Gothenburg, Sweden                 1200                    2100
# Malmo, Sweden                      1100                    2000
# Ankara, Turkiye                     450                     900
# Adana, Turkiye                      350                     800
#
#                    Last Data Update        city   country
# city&country
# Vienna, Austria          2024-06-15      Vienna   Austria
# Salzburg, Austria        2023-11-03    Salzburg   Austria
# Brussels, Belgium        2023-04-22    Brussels   Belgium
# Antwerp, Belgium         2024-08-09     Antwerp   Belgium
# Gent, Belgium            2023-07-17        Gent   Belgium
# ...                             ...         ...       ...
# Stockholm, Sweden        2024-09-11   Stockholm    Sweden
# Gothenburg, Sweden       2023-03-10  Gothenburg    Sweden
# Malmo, Sweden            2024-07-07       Malmo    Sweden
# Ankara, Turkiye          2023-06-08      Ankara   Turkiye
# Adana, Turkiye           2024-05-02       Adana   Turkiye
#
# [84 rows x 14 columns]

# %%
columns=data_copy.columns.to_list()
data_copy = data_copy[columns[-2:] + columns[:-2]]
data_copy
#Putting the city and country columns as the first and second ones: it's better for visualization.
# Out:
#                     Average Cost of Living Last Data Update        city  \
# city&country
# Vienna, Austria                       2061       2024-06-15      Vienna
# Salzburg, Austria                     2186       2023-11-03    Salzburg
# Brussels, Belgium                     1900       2023-04-22    Brussels
# Antwerp, Belgium                      1953       2024-08-09     Antwerp
# Gent, Belgium                         1200       2023-07-17        Gent
# ...                                    ...              ...         ...
# Stockholm, Sweden                     2300       2024-09-11   Stockholm
# Gothenburg, Sweden                    2100       2023-03-10  Gothenburg
# Malmo, Sweden                         2000       2024-07-07       Malmo
# Ankara, Turkiye                        900       2023-06-08      Ankara
# Adana, Turkiye                         800       2024-05-02       Adana
#
#                      country  Population Density  Population  \
# city&country
# Vienna, Austria      Austria               310.0     2983513
# Salzburg, Austria    Austria               243.0      375489
# Brussels, Belgium    Belgium               681.0     3284548
# Antwerp, Belgium     Belgium               928.0     1139663
# Gent, Belgium        Belgium               552.0      645813
# ...                      ...                 ...         ...
# Stockholm, Sweden     Sweden               334.0     2344124
# Gothenburg, Sweden    Sweden               245.0     1037675
# Malmo, Sweden         Sweden               368.0      680335
# Ankara, Turkiye      Turkiye              1922.0     4843511
# Adana, Turkiye       Turkiye               552.0     1074543
#
#                     Working Age Population   Youth Dependency Ratio  \
# city&country
# Vienna, Austria                   2018818.0                    20.1
# Salzburg, Austria                  250472.0                    20.3
# Brussels, Belgium                 2137425.0                    27.5
# Antwerp, Belgium                   723396.0                    27.7
# Gent, Belgium                      417832.0                    24.8
# ...                                     ...                     ...
# Stockholm, Sweden                 1534225.0                    28.5
# Gothenburg, Sweden                 672152.0                    28.2
# Malmo, Sweden                      436271.0                    29.4
# Ankara, Turkiye                   3417691.0                    30.0
# Adana, Turkiye                     718256.0                    37.8
#
#                     Unemployment Rate  GDP per Capita  \
# city&country
# Vienna, Austria                  10.2         55770.0
# Salzburg, Austria                 3.0         66689.0
# Brussels, Belgium                10.7         62500.0
# Antwerp, Belgium                  6.2         57595.0
# Gent, Belgium                     NaN         53311.0
# ...                               ...             ...
# Stockholm, Sweden                 6.2         70950.0
# Gothenburg, Sweden                6.3         49588.0
# Malmo, Sweden                     9.2         44387.0
# Ankara, Turkiye                  14.4         38916.0
# Adana, Turkiye                   12.2         19945.0
#
#                     Days of very strong heat stress  \
# city&country
# Vienna, Austria                                   3
# Salzburg, Austria                                 0
# Brussels, Belgium                                 3
# Antwerp, Belgium                                  3
# Gent, Belgium                                     2
# ...                                             ...
# Stockholm, Sweden                                 0
# Gothenburg, Sweden                                0
# Malmo, Sweden                                     0
# Ankara, Turkiye                                   3
# Adana, Turkiye                                   59
#
#                                 Main Spoken Languages  Average Monthly Salary  \
# city&country
# Vienna, Austria     German, English, Turkish, Serbian                    2500
# Salzburg, Austria                              German                    3200
# Brussels, Belgium      French, Dutch, Arabic, English                    3350
# Antwerp, Belgium                Dutch, French, Arabic                    2609
# Gent, Belgium                           Dutch, French                    2400
# ...                                               ...                     ...
# Stockholm, Sweden                    Swedish, English                    2700
# Gothenburg, Sweden                   Swedish, English                    2500
# Malmo, Sweden                        Swedish, English                    2400
# Ankara, Turkiye                               Turkish                     900
# Adana, Turkiye                                Turkish                     750
#
#                     Avgerage Rent Price
# city&country
# Vienna, Austria                    1050
# Salzburg, Austria                  1100
# Brussels, Belgium                  1200
# Antwerp, Belgium                    900
# Gent, Belgium                       827
# ...                                 ...
# Stockholm, Sweden                  1400
# Gothenburg, Sweden                 1200
# Malmo, Sweden                      1100
# Ankara, Turkiye                     450
# Adana, Turkiye                      350
#
# [84 rows x 14 columns]

# %%
data_copy[data_copy['country']==' Athens']
#row index 43
temp=data_copy.iloc[43,0]
data_copy.iloc[43,0]=data_copy.iloc[43,1]
data_copy.iloc[43,1]=temp
data_copy.iloc[43,:]
#Now Athens and Greece are in the right place
# Out:
# /var/folders/dc/jfb4p3vj5q9dcq1f9lcgzl5c0000gn/T/ipykernel_15050/3551827420.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024-07-16 00:00:00' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data_copy.iloc[43,0]=data_copy.iloc[43,1]
# /var/folders/dc/jfb4p3vj5q9dcq1f9lcgzl5c0000gn/T/ipykernel_15050/3551827420.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1200' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   data_copy.iloc[43,1]=temp
# Average Cost of Living             2024-07-16 00:00:00
# Last Data Update                                  1200
# city                                            Greece
# country                                         Athens
# Population Density                              1829.0
# Population                                     3530371
# Working Age Population                       2287174.0
# Youth Dependency Ratio                            22.0
# Unemployment Rate                                 17.2
# GDP per Capita                                 38580.0
# Days of very strong heat stress                     17
# Main Spoken Languages                   Greek, English
# Average Monthly Salary                            1050
# Avgerage Rent Price                                600
# Name: Greece, Athens, dtype: object

# %%
cities_sum = data_copy['city'].value_counts().sum()
print('In total there are ', cities_sum, 'cities')

cities_count=data_copy['country'].value_counts()
print(cities_count)
# Out:
# In total there are  84 cities
# country
# Germany            9
# Spain              6
# Italy              6
# Netherlands        5
# United Kingdom     5
# Belgium            4
# Portugal           4
# Sweden             3
# Switzerland        3
# Poland             3
# Norway             3
# Hungary            3
# Austria            2
# Ireland            2
# Croatia            2
# Turkiye            2
# Czechia            2
# Bulgaria           2
# France             2
# Finland            2
# Denmark            2
# Slovenia           1
# Slovak Republic    1
# Romania            1
# Cyprus             1
# Greece             1
# Athens             1
# Malta              1
# Latvia             1
# Luxembourg         1
#  France            1
# Estonia            1
# Name: count, dtype: int64

# %% [markdown]
# A total of 84 cities are included in the dataset. Two of them are associated with Greece: Athens and Zagreb.

# %%
data_copy.set_index('country', inplace=True)
data_copy.index
# Out:
# Index([        ' Austria',         ' Austria',         ' Belgium',
#                ' Belgium',         ' Belgium',         ' Belgium',
#               ' Bulgaria',        ' Bulgaria',     ' Switzerland',
#            ' Switzerland',     ' Switzerland',          ' Cyprus',
#                      None,         ' Czechia',         ' Czechia',
#                ' Germany',         ' Germany',         ' Germany',
#                ' Germany',         ' Germany',         ' Germany',
#                ' Germany',         ' Germany',         ' Germany',
#                ' Denmark',         ' Denmark',           ' Spain',
#                  ' Spain',           ' Spain',           ' Spain',
#                  ' Spain',           ' Spain',         ' Estonia',
#                ' Finland',         ' Finland',          ' France',
#                '  France',          ' France',  ' United Kingdom',
#         ' United Kingdom',  ' United Kingdom',  ' United Kingdom',
#         ' United Kingdom',          ' Athens',          ' Greece',
#                ' Croatia',         ' Croatia',         ' Hungary',
#                ' Hungary',         ' Hungary',         ' Ireland',
#                ' Ireland',           ' Italy',           ' Italy',
#                  ' Italy',           ' Italy',           ' Italy',
#                  ' Italy',      ' Luxembourg',          ' Latvia',
#                  ' Malta',     ' Netherlands',     ' Netherlands',
#            ' Netherlands',     ' Netherlands',     ' Netherlands',
#                 ' Norway',          ' Norway',          ' Norway',
#                 ' Poland',          ' Poland',          ' Poland',
#               ' Portugal',        ' Portugal',        ' Portugal',
#               ' Portugal',         ' Romania', ' Slovak Republic',
#               ' Slovenia',          ' Sweden',          ' Sweden',
#                 ' Sweden',         ' Turkiye',         ' Turkiye'],
#       dtype='object', name='country')

# %% [markdown]
# **Question 2.c** Which is the least spoken language in the dataset? Which are the top 3 most spoken languages?

# %%
languages_count=data_copy['Main Spoken Languages'].str.split(', ').explode().value_counts()
languages_count
#Creating a list with all the main spoken languages togheter
# Out:
# Main Spoken Languages
# English              46
# German               13
# French               10
# Turkish               9
# Dutch                 9
# Italian               6
# Spanish               5
# Swedish               4
# Polish                4
# Greek                 4
# Portuguese            4
# Hungarian             3
# Russian               3
# Norwegian             3
# Croatian              2
# Urdu                  2
# Irish Gaelic          2
# Finnish               2
# Danish                2
# Czech                 2
# Bulgarian             2
# Arabic                2
# Maltese               1
# Latvian               1
# Luxembourgish         1
# Slovak                1
# Romanian              1
#   Arabic              1
# Scots Gaelic          1
# Scots                 1
# Bengali               1
# Estonian              1
# Spanish;Valencian     1
# Catalan               1
# Serbian               1
# Slovene               1
# Name: count, dtype: int64

# %% [markdown]
# The top 3 most spoken languages are:
# 1. English (46)
# 2. German (14)
# 3. Turkish (10)
# 3. France (10)
#
# The least spoken languages are: Sloven, Maltese, Latvian, Luxembourgish, Slovak, Romanian, Scots Gaelic, Scots, Bengali, Estonian, Valencian, Catalan and Serbian.

# %% [markdown]
# **Question 3.a** Entries uploaded before April 2023 need to be updated. Which cities would require an update?

# %%
begin_April_23=pd.to_datetime('2023-04-1')
filter=data_copy[data_copy['Last Data Update']< begin_April_23]
filter['city']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 begin_April_23=pd.to_datetime('2023-04-1')
# ----> 2 filter=data_copy[data_copy['Last Data Update']< begin_April_23]
#       3 filter['city']
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/series.py:6130, in Series._cmp_method(self, other, op)
#    6127 lvalues = self._values
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6130 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6132 return self._construct_result(res_values, name=res_name)
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /opt/anaconda3/envs/PDS/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'numpy.int64' and 'Timestamp'

# %% [markdown]
# The cities Basel, Munich, Frankfurt am Main, Lyon, Venice, and Gothenburg require an update, as their most recent data revisions date back to before April 2023.

# %% [markdown]
# **Question 3.b** How many days ago was the last update? On what day, month, and year did it occur?

# %%
date_today= pd.Timestamp('today').normalize()
last_update=max(data_copy['Last Data Update'])
days= (date_today-last_update).days
print('The last update was', days, 'days ago')
print('The last update was on', last_update)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 date_today= pd.Timestamp('today').normalize()
# ----> 2 last_update=max(data_copy['Last Data Update'])
#       3 days= (date_today-last_update).days
#       4 print('The last update was', days, 'days ago')
#
# TypeError: '>' not supported between instances of 'numpy.int64' and 'Timestamp'

# %% [markdown]
# **Question 4.a** How are the Unemployment Rate and GDP per Capita distributed and related? What does this relationship suggest? Provide a visual representation.

# %%
unemployment_rate=data_copy['Unemployment Rate']
GDP_per_capita=data_copy['GDP per Capita']

#We can drop the missing values from these columns
unempl_GDP = data_copy.loc[:, ('Unemployment Rate', 'GDP per Capita')].dropna(subset=["Unemployment Rate", "GDP per Capita"])
unempl_GDP
# Out:
#          Unemployment Rate  GDP per Capita
# country
# Austria               10.2         55770.0
# Austria                3.0         66689.0
# Belgium               10.7         62500.0
# Belgium                6.2         57595.0
# Belgium                5.6         63083.0
# ...                    ...             ...
# Sweden                 6.2         70950.0
# Sweden                 6.3         49588.0
# Sweden                 9.2         44387.0
# Turkiye               14.4         38916.0
# Turkiye               12.2         19945.0
#
# [82 rows x 2 columns]

# %%
#How are Unemployement Rate and GDP per Capita distributed?
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.histplot(unemployment_rate, kde=True, color='skyblue')
plt.title('Distribution of Unemployment Rate')

plt.subplot(1,2,2)
sns.histplot(GDP_per_capita, kde=True, color='lightgreen')
plt.title('Distribution of GDP per Capita')

plt.tight_layout()
plt.show()

# %%
#Relationship between GDP per Capita and Unemployment Rate
plt.figure(figsize=(7,5))
sns.scatterplot(data=unempl_GDP, x= 'Unemployment Rate', y= 'GDP per Capita')
sns.regplot(data=unempl_GDP, x= 'Unemployment Rate', y= 'GDP per Capita', scatter=False, color='red')
plt.title('Relationship between GDP per Capita and Unemployment Rate')
plt.show()

# %% [markdown]
# The scatter plot illustrates the relationship between GDP per Capita and the Unemployment Rate.
# The trend line shows a negative correlation between the two variables: as the unemployment rate increases, GDP per capita tends to decrease. This suggests that cities with higher unemployment rates generally exhibit lower levels of economic productivity per person.
# However, the dispersion of data points indicates a certain degree of variability: some locations deviate from the general trend, showing relatively high GDP per capita even with moderate unemployment rates. The shaded region around the regression line suggest that while the overall relationship is negative, it is not perfectly linear.
# Let's calclulate the Pearson correlation coefficient (we expect it to be negative).

# %%
corr = data_copy['GDP per Capita'].corr(data_copy['Unemployment Rate'])
print(f"Correlation: {corr:.2f}")
# Out:
# Correlation: -0.36

# %% [markdown]
# **Question 4.b** Which are the top 5 cities with the largest difference between the Average Monthly Salary and Average Cost of Living? What about the top 5 countries with the smallest average difference? Show these results with meaningful visualizations.

# %% [markdown]
# **Question 4c** Which is the best city for someone seeking:
# -An average monthly salary above €2000;
# -A cost of living below or equal to €1600, and
# -A country suitable for starting a family (with a relatively larger youth population)?

# %% [markdown]
# **Question 5** What are three additional insights you find meaningful when comparing the given cities?

# %%
#2 INTRERACTIVE MAP
